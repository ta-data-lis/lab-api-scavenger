# %% [markdown]
# # Challenge 1: Fork Languages

# %% [markdown]
#  You will find out how many programming languages are used among all the forks created from the main lab repo of ironhack Madrid. The URL is ironhack-datalabs/madrid-oct-2018, you will:
#
# Obtain the full list of forks created from the main lab repo via Github API.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"] or ["Jupyter Notebook", "HTML", None]

# %%
#I generate a New Token on my Settings/Developer Settings/Personal access tokens (classic)->Ironhack Data Labs Access Token — repo

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import json


url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'
# token = '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'

r = requests.get(url)#, auth=HTTPBasicAuth
r
# Out:
# <Response [200]>

# %%
data = r.json()
'language' in data[0].keys()
# Out:
# True

# %%
list({repo['language'] for repo in data})
# Out:
# ['Jupyter Notebook', 'HTML', None]

# %% [markdown]
# Challenge 2: Count Commits
# From your own lab-list-comprehensions repo, you will count how many commits were made in the past 2 weeks:
#
# Obtain all the commits made in the past 2 weeks via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
url = 'https://api.github.com/repos/AnaCarvalho84/lab-python-list-dict-set-comprehension/commits' #myrepo

params = {'since': '2023-07-14T17:36:05Z'}
r = requests.get(url, params=params)
r
# Out:
# <Response [200]>

# %%
response = requests.get(repo_url)
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"id":216204525,"node_id":"MDEwOlJlcG9zaXRvcnkyMTYyMDQ1MjU=","name":"lab-list-comprehensions","full_name":"ta-data-lis/lab-list-comprehensions","private":false,"owner":{"login":"ta-data-lis","id":54109907,"node_id":"MDQ6VXNlcjU0MTA5OTA3","avatar_url":"https://avatars.githubusercontent.com/u/54109907?v=4","gravatar_id":"","url":"https://api.github.com/users/ta-data-lis","html_url":"https://github.com/ta-data-lis","followers_url":"https://api.github.com/users/ta-data-lis/followers","following_url":"https://api.github.com/users/ta-data-lis/following{/other_user}","gists_url":"https://api.github.com/users/ta-data-lis/gists{/gist_id}","starred_url":"https://api.github.com/users/ta-data-lis/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ta-data-lis/subscriptions","organizations_url":"https://api.github.com/users/ta-data-lis/orgs","repos_url":"https://api.github.com/users/ta-data-lis/repos","events_url":"https://api.github.com/users/ta-data-lis/events{/privacy}"
# ...

# %%
commits = r.json()
commits
# Out:
# [{'sha': '4d78ba1ffd732803012e761844f42d1b0b900dd9',
#   'node_id': 'C_kwDOJ8G_UdoAKDRkNzhiYTFmZmQ3MzI4MDMwMTJlNzYxODQ0ZjQyZDFiMGI5MDBkZDk',
#   'commit': {'author': {'name': 'AnaCarvalho84',
#     'email': '131803922+AnaCarvalho84@users.noreply.github.com',
#     'date': '2023-07-17T17:23:48Z'},
#    'committer': {'name': 'AnaCarvalho84',
#     'email': '131803922+AnaCarvalho84@users.noreply.github.com',
#     'date': '2023-07-17T17:23:48Z'},
#    'message': 'lab done',
#    'tree': {'sha': 'f20e97b13fc223caf731f54ab05e987ed3cb0def',
#     'url': 'https://api.github.com/repos/AnaCarvalho84/lab-python-list-dict-set-comprehension/git/trees/f20e97b13fc223caf731f54ab05e987ed3cb0def'},
#    'url': 'https://api.github.com/repos/AnaCarvalho84/lab-python-list-dict-set-comprehension/git/commits/4d78ba1ffd732803012e761844f42d1b0b900dd9',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
# number of commits objects
len(commits)
# Out:
# 1

# %%
# unpacking all the nested dictionaries in the json
pd.json_normalize(commits)
# Out:
#                                         sha  \
# 0  4d78ba1ffd732803012e761844f42d1b0b900dd9
#
#                                              node_id  \
# 0  C_kwDOJ8G_UdoAKDRkNzhiYTFmZmQ3MzI4MDMwMTJlNzYx...
#
#                                                  url  \
# 0  https://api.github.com/repos/AnaCarvalho84/lab...
#
#                                             html_url  \
# 0  https://github.com/AnaCarvalho84/lab-python-li...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/AnaCarvalho84/lab...
#
#                                              parents commit.author.name  \
# 0  [{'sha': '9c0ad4bae746e88f598f627b3f22d406c415...      AnaCarvalho84
#
#                                 commit.author.email    commit.author.date  \
# 0  131803922+AnaCarvalho84@users.noreply.github.com  2023-07-17T17:23:48Z
#
#   commit.committer.name  ...  \
# 0         AnaCarvalho84  ...
#
#                              committer.following_url  \
# ...

# %%
pd.json_normalize(commits).T
# Out:
#                                                                                0
# sha                                     4d78ba1ffd732803012e761844f42d1b0b900dd9
# node_id                        C_kwDOJ8G_UdoAKDRkNzhiYTFmZmQ3MzI4MDMwMTJlNzYx...
# url                            https://api.github.com/repos/AnaCarvalho84/lab...
# html_url                       https://github.com/AnaCarvalho84/lab-python-li...
# comments_url                   https://api.github.com/repos/AnaCarvalho84/lab...
# parents                        [{'sha': '9c0ad4bae746e88f598f627b3f22d406c415...
# commit.author.name                                                 AnaCarvalho84
# commit.author.email             131803922+AnaCarvalho84@users.noreply.github.com
# commit.author.date                                          2023-07-17T17:23:48Z
# commit.committer.name                                              AnaCarvalho84
# commit.committer.email          131803922+AnaCarvalho84@users.noreply.github.com
# ...
