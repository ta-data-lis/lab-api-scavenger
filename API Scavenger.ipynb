# %%
import requests
import json
import pandas as pd
from requests.auth import HTTPBasicAuth
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'
response = requests.get(url,auth = HTTPBasicAuth('Chris-Howells', 'mytoken'))
results = response.json()
print(results)
# Out:
# [{'id': 259088458, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=', 'name': 'datalis0819', 'full_name': 'edxz7/datalis0819', 'private': False, 'owner': {'login': 'edxz7', 'id': 22061025, 'node_id': 'MDQ6VXNlcjIyMDYxMDI1', 'avatar_url': 'https://avatars1.githubusercontent.com/u/22061025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/edxz7', 'html_url': 'https://github.com/edxz7', 'followers_url': 'https://api.github.com/users/edxz7/followers', 'following_url': 'https://api.github.com/users/edxz7/following{/other_user}', 'gists_url': 'https://api.github.com/users/edxz7/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/edxz7/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/edxz7/subscriptions', 'organizations_url': 'https://api.github.com/users/edxz7/orgs', 'repos_url': 'https://api.github.com/users/edxz7/repos', 'events_url': 'https://api.github.com/users/edxz7/events{/privacy}', 'received_events_url': 'https://api.github.com/users/e
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(results)
# Out:
# <ipython-input-3-23062efc3d59>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(results)
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 10  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 11  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
# ...

# %%
data = pd.DataFrame(results)
data
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 10  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 11  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# 1        Mariana427/datalis0819    False
# 2    EvelienDonkers/datalis0819    False
# ...

# %%
df_languages = data['language']
df_languages.dropna() 
df_languages.drop_duplicates()

#there is only 1 language for the Data Analytics - Ironhack Lisbon profile (jupyter Notebook = python)
# Out:
# 0                None
# 3    Jupyter Notebook
# Name: language, dtype: object

# %%
data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
df_count_commits = data['commits_url', ]
print(df_count_commits)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('commits_url',)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-b0cfbe89ee92> in <module>
# ...

# %%
url = 'https://api.github.com/user'
response = requests.get(url,auth = HTTPBasicAuth('Chris-Howells', 'mytoken'))
response.json()
# Out:
# {'login': 'Chris-Howells',
#  'id': 69651150,
#  'node_id': 'MDQ6VXNlcjY5NjUxMTUw',
#  'avatar_url': 'https://avatars0.githubusercontent.com/u/69651150?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Chris-Howells',
#  'html_url': 'https://github.com/Chris-Howells',
#  'followers_url': 'https://api.github.com/users/Chris-Howells/followers',
#  'following_url': 'https://api.github.com/users/Chris-Howells/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Chris-Howells/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Chris-Howells/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Chris-Howells/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Chris-Howells/orgs',
#  'repos_url': 'https://api.github.com/users/Chris-Howells/repos',
#  'events_url': 'https://api.github.com/users/Chris-Howells/events{/privacy}',
# ...

# %%
url = 'https://api.github.com/repos/ta-data-lis/lab-numpy/commits'
response_1 = requests.get(url,auth = HTTPBasicAuth('Chris-Howells', 'mytoken'))
results_1 = response_1.json()

# %%
df_commit = pd.DataFrame(results_1)
df_commit = pd.json_normalize(results_1)

# %%
df_commit.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
df_count_commits = df_commit['commit.author.date']
print(df_count_commits)
# Out:
# 0    2019-10-23T13:28:37Z
# 1    2019-10-19T13:03:23Z
# Name: commit.author.date, dtype: object

# %%
df_count_commits = df_commit.loc[(df_commit['commit.author.date'] > '2020-11-7')]
df_count_commits
# Out:
# Empty DataFrame
# ...

# %%
df_commit['commit.author.date'] > '2020-11-7'

#there are none within the last two weeks
# Out:
# 0    False
# 1    False
# Name: commit.author.date, dtype: bool

# %%
no_of_commits = (df_commit['commit.author.date'] > '2020-11-7').value_counts()
no_of_commits
# Out:
# False    2
# Name: commit.author.date, dtype: int64
