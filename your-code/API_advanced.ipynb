# %%
import requests
import os
from pprint import pprint
import pandas as pd

# %%
token = os.getenv('')
owner = "ironhack-datalabs"
repo = "python-project-blueprint"
query_url = f"https://api.github.com/repos/ironhack-datalabs/datalis0819/forks"
params = {
    "state": "open",
}
headers = {'MarcIrmler': f'token {token}'}
r = requests.get(query_url, headers=headers, params=params)
pprint(r.json())
# Out:
# [{'archive_url': 'https://api.github.com/repos/edxz7/datalis0819/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/edxz7/datalis0819/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/edxz7/datalis0819/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/edxz7/datalis0819/branches{/branch}',
#   'clone_url': 'https://github.com/edxz7/datalis0819.git',
#   'collaborators_url': 'https://api.github.com/repos/edxz7/datalis0819/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/edxz7/datalis0819/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/edxz7/datalis0819/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/edxz7/datalis0819/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/edxz7/datalis0819/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/edxz7/datalis0819/contributors',
# ...

# %%
results = r.json()
from pandas.io.json import json_normalize
flattened_data = pd.json_normalize(results)
flattened_data.head(5)
# Out:
#           id                           node_id         name  \
# 0  259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
#
#                      full_name  private  \
# 0            edxz7/datalis0819    False
# 1       Mariana427/datalis0819    False
# 2   EvelienDonkers/datalis0819    False
# 3      ta-data-lis/datalis0819    False
# 4  filipamiralopes/datalis0819    False
#
#                                          html_url  \
# 0            https://github.com/edxz7/datalis0819
# 1       https://github.com/Mariana427/datalis0819
# 2   https://github.com/EvelienDonkers/datalis0819
# 3      https://github.com/ta-data-lis/datalis0819
# 4  https://github.com/filipamiralopes/datalis0819
#
# ...

# %%
language_urls = [repo['languages_url'] for repo in r.json()]

# %%
from requests.auth import HTTPBasicAuth

# %%
lst = [requests.get(lang_url,auth = HTTPBasicAuth("MarcIrmler","7f337f1f9a9dc3f5c98258b415595e82021f363e")).json() for lang_url in language_urls]

# %%
test = []
for i in lst:
    test.append(list(i.keys()))
    
print(test)
# Out:
# [['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python', 'TSQL'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python', 'TSQL'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'TSQL', 'Python']]

# %%
flatten= [j for i in test for j in i]

# %%
print(set(flatten))
# Out:
# {'Jupyter Notebook', 'TSQL', 'HTML', 'Python'}

# %%
token = os.getenv('')
owner = "ironhack-datalabs"
repo = "python-project-blueprint"
query_url = f"https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/stats/commit_activity"
params = {
    "state": "open",
}
headers = {'MarcIrmler': f'token {token}'}
r = requests.get(query_url, headers=headers, params=params)
pprint(r.json())
# Out:
# [{'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1574553600},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1575158400},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1575763200},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1576368000},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1576972800},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1577577600},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1578182400},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1578787200},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1579392000},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1579996800},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1580601600},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1581206400},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1581811200},
#  {'days': [0, 0, 0, 0, 0, 0, 0], 'total': 0, 'week': 1582416000},
# ...

# %%
commit = pd.DataFrame(r.json())

# %%
commit['total'].sum()
# Out:
# 0
