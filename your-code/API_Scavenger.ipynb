# %%
import requests
import json
import pandas as pd
import numpy as np
from requests.auth import HTTPBasicAuth
from getpass import getpass

# %%
url = "https://api.github.com/user"

key = "6c721ef09a05dd638eb138aa23a6a4118d0f6748"

headers = {"Authorization":"Token " + key}

# %%
repo = requests.get(url, headers = headers)

print(repo.status_code)

repo.json()
# Out:
# 200
# {'login': 'Falapas',
#  'id': 72476620,
#  'node_id': 'MDQ6VXNlcjcyNDc2NjIw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/72476620?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Falapas',
#  'html_url': 'https://github.com/Falapas',
#  'followers_url': 'https://api.github.com/users/Falapas/followers',
#  'following_url': 'https://api.github.com/users/Falapas/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Falapas/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Falapas/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Falapas/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Falapas/orgs',
#  'repos_url': 'https://api.github.com/users/Falapas/repos',
#  'events_url': 'https://api.github.com/users/Falapas/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Falapas/received_events',
#  'type': 'User',
#  'site_admin': False,
# ...

# %%
#Getting all my repos

url = repo.json()["repos_url"]

repo = requests.get(url, headers = headers)

print(repo.status_code)

repo.json()
# Out:
# 200
# [{'id': 318903042,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTg5MDMwNDI=',
#   'name': 'lab-advanced-regex',
#   'full_name': 'Falapas/lab-advanced-regex',
#   'private': False,
#   'owner': {'login': 'Falapas',
#    'id': 72476620,
#    'node_id': 'MDQ6VXNlcjcyNDc2NjIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72476620?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Falapas',
#    'html_url': 'https://github.com/Falapas',
#    'followers_url': 'https://api.github.com/users/Falapas/followers',
#    'following_url': 'https://api.github.com/users/Falapas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Falapas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Falapas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Falapas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Falapas/orgs',
# ...

# %%
#Getting my pre-work repo

url = "https://api.github.com/repos/Falapas/pre_work_data_analytics"

response = requests.get(url, headers = headers)

print(response.status_code)

response.json()
# Out:
# 200
# {'id': 305065633,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMDUwNjU2MzM=',
#  'name': 'pre_work_data_analytics',
#  'full_name': 'Falapas/pre_work_data_analytics',
#  'private': False,
#  'owner': {'login': 'Falapas',
#   'id': 72476620,
#   'node_id': 'MDQ6VXNlcjcyNDc2NjIw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72476620?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Falapas',
#   'html_url': 'https://github.com/Falapas',
#   'followers_url': 'https://api.github.com/users/Falapas/followers',
#   'following_url': 'https://api.github.com/users/Falapas/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Falapas/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Falapas/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Falapas/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Falapas/orgs',
#   'repos_url': 'https://api.github.com/users/Falapas/repos',
# ...

# %%
# Getting all forks from main lab repo

url = "https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019-prework/forks"

repo = requests.get(url, headers = headers)

print(repo.status_code)

repo.json()
# Out:
# 200
# [{'id': 331979962,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzE5Nzk5NjI=',
#   'name': 'bcn-feb-2019-prework',
#   'full_name': 'vonate5/bcn-feb-2019-prework',
#   'private': False,
#   'owner': {'login': 'vonate5',
#    'id': 77745562,
#    'node_id': 'MDQ6VXNlcjc3NzQ1NTYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77745562?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vonate5',
#    'html_url': 'https://github.com/vonate5',
#    'followers_url': 'https://api.github.com/users/vonate5/followers',
#    'following_url': 'https://api.github.com/users/vonate5/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vonate5/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vonate5/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vonate5/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vonate5/orgs',
# ...

# %%
#Getting the languages from the main lab repo

languages_list = []

for item in repo.json():
    if item["language"] != None:
        languages_list.append(item["language"])
    
print(list(set(languages_list)))
# Out:
# ['Jupyter Notebook']

# %%
# Getting all commits from repo

url = "https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits"

repo = requests.get(url, headers = headers)

print(repo.status_code)

repo.json()
# Out:
# 200
# [{'sha': '6a243303cfd846faac16417cad54cd40ab3f82c6',
#   'node_id': 'MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2ZmFhYzE2NDE3Y2FkNTRjZDQwYWIzZjgyYzY=',
#   'commit': {'author': {'name': 'Carlos Madriz',
#     'email': '45972288+carlosmd14@users.noreply.github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '5696a145dbbeef9a0417d852b706178bbca30900',
#     'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/trees/5696a145dbbeef9a0417d852b706178bbca30900'},
#    'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/commits/6a243303cfd846faac16417cad54cd40ab3f82c6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
df_commit = pd.DataFrame(repo.json())
df_commit
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carla Mendes', 'email': '...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
#Counting number of commits

print(len(list(df_commit["commit"])))
# Out:
# 4
