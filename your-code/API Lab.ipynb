# %%
import requests
import json
import pandas as pd
from requests.auth import HTTPBasicAuth
from getpass import getpass

# %%
## Connexion to GIT HUB

access_token = "094de4985ea4e8ca0eedc679d9c1eb43af6de9a9"
url = " https://api.github.com/user"

headers = {'Authorization':"Token "+access_token}
repo=requests.get(url,headers=headers)

# This will prompt you for a password
repo=requests.get(url,headers=headers)
print(repo.status_code)
repo.json()
# Out:
# 200
# {'login': 'MariaEstebanDA',
#  'id': 72495380,
#  'node_id': 'MDQ6VXNlcjcyNDk1Mzgw',
#  'avatar_url': 'https://avatars3.githubusercontent.com/u/72495380?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/MariaEstebanDA',
#  'html_url': 'https://github.com/MariaEstebanDA',
#  'followers_url': 'https://api.github.com/users/MariaEstebanDA/followers',
#  'following_url': 'https://api.github.com/users/MariaEstebanDA/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/MariaEstebanDA/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/MariaEstebanDA/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/MariaEstebanDA/subscriptions',
#  'organizations_url': 'https://api.github.com/users/MariaEstebanDA/orgs',
#  'repos_url': 'https://api.github.com/users/MariaEstebanDA/repos',
#  'events_url': 'https://api.github.com/users/MariaEstebanDA/events{/privacy}',
# ...

# %% [markdown]
# # Challenge 1: Fork Languages

# %%
# 1. Enter into "my repos" folder

url = "https://api.github.com/users/MariaEstebanDA/repos"

response = requests.get(url,headers=headers)
print(response.status_code)
response.json()
# Out:
# 200
# [{'id': 315132272,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTUxMzIyNzI=',
#   'name': '2nd-Project',
#   'full_name': 'MariaEstebanDA/2nd-Project',
#   'private': False,
#   'owner': {'login': 'MariaEstebanDA',
#    'id': 72495380,
#    'node_id': 'MDQ6VXNlcjcyNDk1Mzgw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/72495380?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MariaEstebanDA',
#    'html_url': 'https://github.com/MariaEstebanDA',
#    'followers_url': 'https://api.github.com/users/MariaEstebanDA/followers',
#    'following_url': 'https://api.github.com/users/MariaEstebanDA/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MariaEstebanDA/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MariaEstebanDA/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MariaEstebanDA/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MariaEstebanDA/orgs',
# ...

# %%
# 2. Enter into my "bcn-feb-2019" repo

url = "https://api.github.com/repos/MariaEstebanDA/bcn-feb-2019"

response = requests.get(url,headers=headers)
print(response.status_code)
response.json()
# Out:
# 200
# {'id': 319429421,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMTk0Mjk0MjE=',
#  'name': 'bcn-feb-2019',
#  'full_name': 'MariaEstebanDA/bcn-feb-2019',
#  'private': False,
#  'owner': {'login': 'MariaEstebanDA',
#   'id': 72495380,
#   'node_id': 'MDQ6VXNlcjcyNDk1Mzgw',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/72495380?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MariaEstebanDA',
#   'html_url': 'https://github.com/MariaEstebanDA',
#   'followers_url': 'https://api.github.com/users/MariaEstebanDA/followers',
#   'following_url': 'https://api.github.com/users/MariaEstebanDA/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MariaEstebanDA/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MariaEstebanDA/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MariaEstebanDA/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MariaEstebanDA/orgs',
# ...

# %%
# 3. Enter into the main "bcn-feb-2019" repo and in the "forks" section

url = "https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks"

response = requests.get(url,headers=headers)
print(response.status_code)
response.json()
# Out:
# 200
# [{'id': 319429421,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTk0Mjk0MjE=',
#   'name': 'bcn-feb-2019',
#   'full_name': 'MariaEstebanDA/bcn-feb-2019',
#   'private': False,
#   'owner': {'login': 'MariaEstebanDA',
#    'id': 72495380,
#    'node_id': 'MDQ6VXNlcjcyNDk1Mzgw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/72495380?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MariaEstebanDA',
#    'html_url': 'https://github.com/MariaEstebanDA',
#    'followers_url': 'https://api.github.com/users/MariaEstebanDA/followers',
#    'following_url': 'https://api.github.com/users/MariaEstebanDA/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MariaEstebanDA/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MariaEstebanDA/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MariaEstebanDA/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MariaEstebanDA/orgs',
# ...

# %%
# 4. Converting the "Main/Fork" response to a dataframe

forks_df = pd.DataFrame(response.json())
forks_df
# Out:
#           id                           node_id          name  \
# 0  319429421  MDEwOlJlcG9zaXRvcnkzMTk0Mjk0MjE=  bcn-feb-2019
# 1  318578020  MDEwOlJlcG9zaXRvcnkzMTg1NzgwMjA=  bcn-feb-2019
# 2  278336683  MDEwOlJlcG9zaXRvcnkyNzgzMzY2ODM=  bcn-feb-2019
# 3  276718167  MDEwOlJlcG9zaXRvcnkyNzY3MTgxNjc=  bcn-feb-2019
#
#                      full_name  private  \
# 0  MariaEstebanDA/bcn-feb-2019    False
# 1     je-nakajima/bcn-feb-2019    False
# 2       franbaldi/bcn-feb-2019    False
# 3   brunacarolino/bcn-feb-2019    False
#
#                                                owner  \
# 0  {'login': 'MariaEstebanDA', 'id': 72495380, 'n...
# 1  {'login': 'je-nakajima', 'id': 71846807, 'node...
# 2  {'login': 'franbaldi', 'id': 25199469, 'node_i...
# 3  {'login': 'brunacarolino', 'id': 67610079, 'no...
#
#                                          html_url description  fork  \
# 0  https://github.com/MariaEstebanDA/bcn-feb-2019        None  True
# ...

# %%
# 5. Not all columns are displayed. Code to see all columns up to 100. This applies to all dataframes in the Notebook

pd.set_option("display.max_columns",100)

# %%
# 6. Get the languages

languages = forks_df["language"].unique()

languages
# Out:
# array([None, 'Jupyter Notebook'], dtype=object)

# %% [markdown]
# # Challenge 2: Count Commits

# %%
# Q1: Obtain all the commits made in the past 2 weeks via API, which is a JSON array that contains multiple commit objects.
    

# 1. Access the commits URL 

url = "https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/commits"

response = requests.get(url,headers=headers)
print(response.status_code)
response.json()
# Out:
# 200
# [{'sha': '20b6f1358ebbd2b1f7000993e6712f7713c966d7',
#   'node_id': 'MDY6Q29tbWl0MTY5NjA1MDkyOjIwYjZmMTM1OGViYmQyYjFmNzAwMDk5M2U2NzEyZjc3MTNjOTY2ZDc=',
#   'commit': {'author': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2019-02-18T21:44:58Z'},
#    'committer': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2019-02-18T21:44:58Z'},
#    'message': 'graph theory PLACEHOLDER',
#    'tree': {'sha': '195dc8de83b6a18f50e0d2d8a1d0efa32408a381',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/trees/195dc8de83b6a18f50e0d2d8a1d0efa32408a381'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/commits/20b6f1358ebbd2b1f7000993e6712f7713c966d7',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
# Converting the "Commit" response to a dataframe

commit_df = pd.DataFrame(response.json())
commit_df
# Out:
#                                          sha  \
# 0   20b6f1358ebbd2b1f7000993e6712f7713c966d7
# 1   a0c4ff166919fabf181ed81e546e22f557e81b84
# 2   309aab430a57c5c77ebbb04979f26db75f8cf499
# 3   3c78444b02060b91dd927a70d6f440e824b74e3e
# 4   cb523aa22e6680474fd7c537e4ada95f22a8e90a
# 5   d11739f76404928399137555b390c7ce005c6fb5
# 6   f5733e967be4adab6e5af3cc742085248de46f52
# 7   f517e5c58e7c223af62c19353c2ed012d51e79e9
# 8   01b9e6de54ae7bf17c0b707952a371a0a1d7b3d8
# 9   d7c76322fb493553b74b48b4d0d48695ab0721c7
# 10  6ed1e8d87617cbd92029734becd08f28c5ae7bd9
# 11  6a8d29ec38e08994243b9804d2df879529a42ee9
# 12  d057cc6ec63837aaf6461a1e3c1d04b6feb1c0ec
# 13  43472c1139f0284738c0adade2473222e835619a
# 14  b67a840e89693a41ece26555d63f63b745ac1331
# 15  69756e7490e4737a86d3b214ba36fb3edc32da8a
# 16  d6dc4006e7eb868ecb3e62b84a9d47bab288b4ae
# 17  be4a05118934b94de3b736707e95373ef7240a17
# 18  0be9a4d8ddf94c014f031eb6d19c96d70e7d794a
# 19  6dc95195317949ce9a9023034cc464351315145e
# ...

# %%
# Q2: Count how many commit objects are contained in the array.

commit_df.shape

# 30 commits were made
# Out:
# (30, 9)
