# %% [markdown]
# # API Scavenger Hunt

# %% [markdown]
# ## Challenge 1

# %%
import requests
import json
import pandas as pd
from requests.auth import HTTPBasicAuth
from getpass import getpass

# %%
#url = 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks'
#url = 'https://api.github.com/repos/ta-data-lis/lab-api-scavenger/forks'
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
response.headers
# Out:
# {'Date': 'Mon, 03 Feb 2020 15:11:46 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Server': 'GitHub.com', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '49', 'X-RateLimit-Reset': '1580743168', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding', 'ETag': 'W/"90b4314e5aa6c908c4990521bd6fb816"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "defaul
# ...

# %%
response.text
# Out:
# '[{"id":219552641,"node_id":"MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=","name":"datalis0819","full_name":"Mariana427/datalis0819","private":false,"owner":{"login":"Mariana427","id":54869432,"node_id":"MDQ6VXNlcjU0ODY5NDMy","avatar_url":"https://avatars2.githubusercontent.com/u/54869432?v=4","gravatar_id":"","url":"https://api.github.com/users/Mariana427","html_url":"https://github.com/Mariana427","followers_url":"https://api.github.com/users/Mariana427/followers","following_url":"https://api.github.com/users/Mariana427/following{/other_user}","gists_url":"https://api.github.com/users/Mariana427/gists{/gist_id}","starred_url":"https://api.github.com/users/Mariana427/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Mariana427/subscriptions","organizations_url":"https://api.github.com/users/Mariana427/orgs","repos_url":"https://api.github.com/users/Mariana427/repos","events_url":"https://api.github.com/users/Mariana427/events{/privacy}","received_events_url":"https://api
# ...

# %%
ds = pd.DataFrame(response.json())
ds.head()
# Out:
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
#
#                      full_name  private  \
# 0       Mariana427/datalis0819    False
# 1   EvelienDonkers/datalis0819    False
# 2      ta-data-lis/datalis0819    False
# 3             Inrx/datalis0819    False
# 4  filipamiralopes/datalis0819    False
#
#                                                owner  \
# 0  {'login': 'Mariana427', 'id': 54869432, 'node_...
# 1  {'login': 'EvelienDonkers', 'id': 55210096, 'n...
# 2  {'login': 'ta-data-lis', 'id': 54109907, 'node...
# 3  {'login': 'Inrx', 'id': 49349821, 'node_id': '...
# 4  {'login': 'filipamiralopes', 'id': 42877871, '...
#
# ...

# %%
from pandas.io.json import json_normalize

norm_json = json_normalize(response.json()) # unpack json and normalize if there is the need
ds_normalized = pd.DataFrame(norm_json) # make it into a dataframe
ds_normalized.head()
# Out:
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
#
#                      full_name  private  \
# 0       Mariana427/datalis0819    False
# 1   EvelienDonkers/datalis0819    False
# 2      ta-data-lis/datalis0819    False
# 3             Inrx/datalis0819    False
# 4  filipamiralopes/datalis0819    False
#
#                                          html_url  \
# 0       https://github.com/Mariana427/datalis0819
# 1   https://github.com/EvelienDonkers/datalis0819
# 2      https://github.com/ta-data-lis/datalis0819
# 3             https://github.com/Inrx/datalis0819
# 4  https://github.com/filipamiralopes/datalis0819
#
# ...

# %%
ds_normalized['language']
# Out:
# 0                 None
# 1                 None
# 2     Jupyter Notebook
# 3     Jupyter Notebook
# 4     Jupyter Notebook
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10    Jupyter Notebook
# 11    Jupyter Notebook
# Name: language, dtype: object

# %%
list(set(ds_normalized['language']))
# Out:
# [None, 'Jupyter Notebook']

# %%
ds_normalized.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %% [markdown]
# ## Challenge 2

# %%
url = 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
ds = pd.DataFrame(response.json())
ds.head()
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carla Mendes', 'email': '...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
from pandas.io.json import json_normalize

norm_json = json_normalize(response.json()) # unpack json and normalize if there is the need
ds_normalized = pd.DataFrame(norm_json) # make it into a dataframe
ds_normalized.head()
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# 2  https://api.github.com/repos/ta-data-lis/lab-m...
# 3  https://api.github.com/repos/ta-data-lis/lab-m...
#
#                                             html_url  \
# 0  https://github.com/ta-data-lis/lab-mysql-first...
# 1  https://github.com/ta-data-lis/lab-mysql-first...
# ...

# %%
ds_normalized.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
# This gives us the column which has the commit dates
ds_normalized['commit.author.date']
# Out:
# 0    2019-08-19T11:12:15Z
# 1    2019-08-19T11:11:55Z
# 2    2019-08-19T11:10:23Z
# 3    2019-08-19T08:36:54Z
# Name: commit.author.date, dtype: object

# %%
# This tells us there are 4 commits
len(ds_normalized['commit.author.date'])
# Out:
# 4
