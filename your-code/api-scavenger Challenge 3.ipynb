# %%
import requests
import json 
import pandas as pd

# %%
url = "https://api.github.com/repos/ironhack-datalabs/scavenger/forks"

# get method from requests
response = requests.get(url).json()

# check if you have the info
response
ds = pd.DataFrame(response)
ds.head()
# Out:
#           id                           node_id       name  \
# 0  198400783  MDEwOlJlcG9zaXRvcnkxOTg0MDA3ODM=  scavenger
# 1  197437946  MDEwOlJlcG9zaXRvcnkxOTc0Mzc5NDY=  scavenger
# 2  197113443  MDEwOlJlcG9zaXRvcnkxOTcxMTM0NDM=  scavenger
# 3  196638669  MDEwOlJlcG9zaXRvcnkxOTY2Mzg2Njk=  scavenger
#
#              full_name  private  \
# 0   Lauminja/scavenger    False
# 1  orianegsx/scavenger    False
# 2  diequicar/scavenger    False
# 3    EiroaMD/scavenger    False
#
#                                                owner  \
# 0  {'login': 'Lauminja', 'id': 50074203, 'node_id...
# 1  {'login': 'orianegsx', 'id': 7051636, 'node_id...
# 2  {'login': 'diequicar', 'id': 51352066, 'node_i...
# 3  {'login': 'EiroaMD', 'id': 49128370, 'node_id'...
#
#                                  html_url description  fork  \
# 0   https://github.com/Lauminja/scavenger        None  True
# 1  https://github.com/orianegsx/scavenger        None  True
# 2  https://github.com/diequicar/scavenger        None  True
# 3    https://github.com/EiroaMD/scavenger        None  True
#
#                                                 url  ... forks_count  \
# 0   https://api.github.com/repos/Lauminja/scavenger  ...           0
# 1  https://api.github.com/repos/orianegsx/scavenger  ...           0
# 2  https://api.github.com/repos/diequicar/scavenger  ...           0
# 3    https://api.github.com/repos/EiroaMD/scavenger  ...           0
#
#   mirror_url archived disabled open_issues_count license forks open_issues  \
# 0       None    False    False                 0    None     0           0
# 1       None    False    False                 0    None     0           0
# 2       None    False    False                 0    None     0           0
# 3       None    False    False                 0    None     0           0
#
#   watchers default_branch
# 0        0         master
# 1        0         master
# 2        0         master
# 3        0         master
#
# [4 rows x 73 columns]

# %%
ds.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license',
#        'forks', 'open_issues', 'watchers', 'default_branch'],
#       dtype='object')

# %%
ds[["name","blobs_url"]]
# Out:
#         name                                          blobs_url
# 0  scavenger  https://api.github.com/repos/Lauminja/scavenge...
# 1  scavenger  https://api.github.com/repos/orianegsx/scaveng...
# 2  scavenger  https://api.github.com/repos/diequicar/scaveng...
# 3  scavenger  https://api.github.com/repos/EiroaMD/scavenger...
