# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import getpass

# %%
url = 'https://api.github.com/user'
password = getpass.getpass()

response = requests.get(url, auth=HTTPBasicAuth('joanarnogueira', password))

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'login': 'joanarnogueira',
#  'id': 109302097,
#  'node_id': 'U_kgDOBoPRUQ',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/109302097?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/joanarnogueira',
#  'html_url': 'https://github.com/joanarnogueira',
#  'followers_url': 'https://api.github.com/users/joanarnogueira/followers',
#  'following_url': 'https://api.github.com/users/joanarnogueira/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/joanarnogueira/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/joanarnogueira/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/joanarnogueira/subscriptions',
#  'organizations_url': 'https://api.github.com/users/joanarnogueira/orgs',
#  'repos_url': 'https://api.github.com/users/joanarnogueira/repos',
#  'events_url': 'https://api.github.com/users/joanarnogueira/events{/privacy}',
# ...

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/languages'


response = requests.get(url=url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'Jupyter Notebook': 1134241, 'HTML': 498316, 'Python': 8691}

# %%
languages_dict = response.json()
languages = list(languages_dict.keys())
languages
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
#Challenge 2

url = 'https://api.github.com/repos/joanarnogueira/lab-list-comprehensions/commits'

response = requests.get(url=url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'sha': 'e7a4b83e312d3211a836748c224118299c7d63c3',
#   'node_id': 'C_kwDOIHyCLNoAKGU3YTRiODNlMzEyZDMyMTFhODM2NzQ4YzIyNDExODI5OWM3ZDYzYzM',
#   'commit': {'author': {'name': 'Joana Nogueira',
#     'email': 'joanarng@gmail.com',
#     'date': '2022-10-09T13:19:57Z'},
#    'committer': {'name': 'Joana Nogueira',
#     'email': 'joanarng@gmail.com',
#     'date': '2022-10-09T13:19:57Z'},
#    'message': 'lab completed',
#    'tree': {'sha': 'ba39ee05696b8da94e78ae7a65194fc4f484597a',
#     'url': 'https://api.github.com/repos/joanarnogueira/lab-list-comprehensions/git/trees/ba39ee05696b8da94e78ae7a65194fc4f484597a'},
#    'url': 'https://api.github.com/repos/joanarnogueira/lab-list-comprehensions/git/commits/e7a4b83e312d3211a836748c224118299c7d63c3',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
new_df = pd.DataFrame(response.json())

# %%
new_df
# Out:
#                                         sha  \
# 0  e7a4b83e312d3211a836748c224118299c7d63c3
# 1  0ef1124f9a48ae5011e21e85ca238771793dd2d9
# 2  8949a53afaeae22f5ce7eba669b73c4479c93542
# 3  5621b3256668f9a15172d79124be70933faba2d9
# 4  80d757c463929428fcc3257b8f48d811a66dc6cc
#
#                                              node_id  \
# 0  C_kwDOIHyCLNoAKGU3YTRiODNlMzEyZDMyMTFhODM2NzQ4...
# 1  C_kwDOIHyCLNoAKDBlZjExMjRmOWE0OGFlNTAxMWUyMWU4...
# 2  MDY6Q29tbWl0NTQ1MDMwNzAwOjg5NDlhNTNhZmFlYWUyMm...
# 3  MDY6Q29tbWl0NTQ1MDMwNzAwOjU2MjFiMzI1NjY2OGY5YT...
# 4  MDY6Q29tbWl0NTQ1MDMwNzAwOjgwZDc1N2M0NjM5Mjk0Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Joana Nogueira', 'email':...
# 1  {'author': {'name': 'Joana Nogueira', 'email':...
# 2  {'author': {'name': 'carlosmd14', 'email': 'ca...
# 3  {'author': {'name': 'carlosmd14', 'email': 'ca...
# 4  {'author': {'name': 'carlosmd14', 'email': 'ca...
#
# ...

# %%
commit_df = new_df['commit']

# %%
len(commit_df)
# Out:
# 5
