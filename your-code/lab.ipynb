# %%
import requests

# %%
# Challenge 1: fork languages
# main lab repo is ironhack-datalabs/datalis0819/

url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

# %%
from requests.auth import HTTPBasicAuth
from getpass import getpass

#don't run this again
response = requests.get(url, auth=HTTPBasicAuth('cfmago', getpass()))
# Out:
# ········

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'id': 259088458,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=',
#   'name': 'datalis0819',
#   'full_name': 'edxz7/datalis0819',
#   'private': False,
#   'owner': {'login': 'edxz7',
#    'id': 22061025,
#    'node_id': 'MDQ6VXNlcjIyMDYxMDI1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/22061025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edxz7',
#    'html_url': 'https://github.com/edxz7',
#    'followers_url': 'https://api.github.com/users/edxz7/followers',
#    'following_url': 'https://api.github.com/users/edxz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edxz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edxz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edxz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edxz7/orgs',
#    'repos_url': 'https://api.github.com/users/edxz7/repos',
# ...

# %%
#I get an error
dict(response.json()).keys()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d29e762f93ef> in <module>
# ----> 1 dict(response.json()).keys()
#
# ValueError: dictionary update sequence element #0 has length 74; 2 is required

# %%
import pandas as pd

# %%
pd.DataFrame(response.json())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b41221fb3911> in <module>
# ----> 1 pd.DataFrame(response.json())
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'json'

# %%
response = pd.json_normalize(response.json())
response
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c4ef46d9621a> in <module>
# ----> 1 response = pd.json_normalize(response.json())
#       2 response
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'json'

# %%
response.shape
# Out:
# (13, 97)

# %%
response
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# ...

# %%
response.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
languages = []

for language in response['language']:
    if language not in languages:
        languages.append(language)

# %%
# now in list comprehension

# %%
print(languages)
#There is only one language, in fact
#Add if statsment to ignore None
# Out:
# [None, 'Jupyter Notebook']

# %%
response['language']
# Out:
# 0                 None
# 1                 None
# 2                 None
# 3     Jupyter Notebook
# 4     Jupyter Notebook
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10    Jupyter Notebook
# 11    Jupyter Notebook
# 12    Jupyter Notebook
# Name: language, dtype: object

# %%
# challenge 2: count commits

# repo is cfmago/lab-numpy
# https://developer.github.com/v3/repos/commits/
# GET /repos/:owner/:repo/commits

url = 'https://api.github.com/repos/cfmago/lab-numpy/commits'

# %%
#don't run this again
response = requests.get(url, auth=HTTPBasicAuth('cfmago', getpass()))
# Out:
# ········

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'sha': '0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
#   'node_id': 'MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3YjU5ODNhNDRhYmM5YTc5ZjI3MmJjNzYzY2I=',
#   'commit': {'author': {'name': 'cfmago',
#     'email': 'cfm.agostinho@gmail.com',
#     'date': '2020-07-04T09:24:27Z'},
#    'committer': {'name': 'cfmago',
#     'email': 'cfm.agostinho@gmail.com',
#     'date': '2020-07-04T09:24:27Z'},
#    'message': 'Small change to main.ipynb',
#    'tree': {'sha': '79a14152afc84540d209a91144ddb96737323f94',
#     'url': 'https://api.github.com/repos/cfmago/lab-numpy/git/trees/79a14152afc84540d209a91144ddb96737323f94'},
#    'url': 'https://api.github.com/repos/cfmago/lab-numpy/git/commits/0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/cfmago/lab-numpy/commits/0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
# ...

# %%
#Again I get an error
dict(response.json()).keys()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-250f1ddc1695> in <module>
#       1 #Again I get an error
# ----> 2 dict(response.json()).keys()
#
# ValueError: dictionary update sequence element #0 has length 9; 2 is required

# %%
pd.DataFrame(response.json())
# Out:
#                                         sha  \
# 0  0b0b90ef6e88e7b5983a44abc9a79f272bc763cb
# 1  12edeef77ab7a9fe77ff94abc6ae0b35537a8d4f
# 2  b659318669c0d35668945c240433e313128db1cd
# 3  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 4  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3Yj...
# 1  MDY6Q29tbWl0Mjc2NjIwNjY0OjEyZWRlZWY3N2FiN2E5Zm...
# 2  MDY6Q29tbWl0Mjc2NjIwNjY0OmI2NTkzMTg2NjljMGQzNT...
# 3  MDY6Q29tbWl0Mjc2NjIwNjY0OjMyMTgyYTVmZjUyZWZjNW...
# 4  MDY6Q29tbWl0Mjc2NjIwNjY0OjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                               commit  \
# 0  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
# 1  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
# 2  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
# 3  {'author': {'name': 'carlosmd14', 'email': 'ca...
# 4  {'author': {'name': 'carlosmd14', 'email': 'ca...
#
# ...

# %%
response = pd.json_normalize(response.json())
response
# Out:
#                                         sha  \
# 0  0b0b90ef6e88e7b5983a44abc9a79f272bc763cb
# 1  12edeef77ab7a9fe77ff94abc6ae0b35537a8d4f
# 2  b659318669c0d35668945c240433e313128db1cd
# 3  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 4  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3Yj...
# 1  MDY6Q29tbWl0Mjc2NjIwNjY0OjEyZWRlZWY3N2FiN2E5Zm...
# 2  MDY6Q29tbWl0Mjc2NjIwNjY0OmI2NTkzMTg2NjljMGQzNT...
# 3  MDY6Q29tbWl0Mjc2NjIwNjY0OjMyMTgyYTVmZjUyZWZjNW...
# 4  MDY6Q29tbWl0Mjc2NjIwNjY0OjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                                  url  \
# 0  https://api.github.com/repos/cfmago/lab-numpy/...
# 1  https://api.github.com/repos/cfmago/lab-numpy/...
# 2  https://api.github.com/repos/cfmago/lab-numpy/...
# 3  https://api.github.com/repos/cfmago/lab-numpy/...
# 4  https://api.github.com/repos/cfmago/lab-numpy/...
#
# ...

# %%
response.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
response.shape
# Out:
# (5, 57)

# %%
response['commit.committer.date']
# Out:
# 0    2020-07-04T09:24:27Z
# 1    2020-07-03T10:26:56Z
# 2    2020-07-02T12:13:18Z
# 3    2019-10-23T13:28:37Z
# 4    2019-10-19T13:03:23Z
# Name: commit.committer.date, dtype: object

# %%
response['commit.committer.date'].dtypes
# Out:
# dtype('O')

# %%
type(response['commit.committer.date'][0])
# Out:
# str

# %%
#condition = (response['commit.author.date'] > "2019-12-22T08:45:43Z")


condition = (response['commit.committer.date'] > "2019-10-23T13:28:37Z")

response[condition]
response[condition].count().head(1)

#There were 3 commits in the last three weeks
# Out:
# sha    3
# dtype: int64

# %%
#with parameters

url = 'https://api.github.com/repos/cfmago/lab-numpy/commits'

inputs = {
    'since' : "2020-06-29"
}

response = requests.get(url, inputs, auth=HTTPBasicAuth('cfmago', getpass()))
# Out:
# ········

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'sha': '0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
#   'node_id': 'MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3YjU5ODNhNDRhYmM5YTc5ZjI3MmJjNzYzY2I=',
#   'commit': {'author': {'name': 'cfmago',
#     'email': 'cfm.agostinho@gmail.com',
#     'date': '2020-07-04T09:24:27Z'},
#    'committer': {'name': 'cfmago',
#     'email': 'cfm.agostinho@gmail.com',
#     'date': '2020-07-04T09:24:27Z'},
#    'message': 'Small change to main.ipynb',
#    'tree': {'sha': '79a14152afc84540d209a91144ddb96737323f94',
#     'url': 'https://api.github.com/repos/cfmago/lab-numpy/git/trees/79a14152afc84540d209a91144ddb96737323f94'},
#    'url': 'https://api.github.com/repos/cfmago/lab-numpy/git/commits/0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/cfmago/lab-numpy/commits/0b0b90ef6e88e7b5983a44abc9a79f272bc763cb',
# ...

# %%
pd.DataFrame(response.json())
# Out:
#                                         sha  \
# 0  0b0b90ef6e88e7b5983a44abc9a79f272bc763cb
# 1  12edeef77ab7a9fe77ff94abc6ae0b35537a8d4f
# 2  b659318669c0d35668945c240433e313128db1cd
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3Yj...
# 1  MDY6Q29tbWl0Mjc2NjIwNjY0OjEyZWRlZWY3N2FiN2E5Zm...
# 2  MDY6Q29tbWl0Mjc2NjIwNjY0OmI2NTkzMTg2NjljMGQzNT...
#
#                                               commit  \
# 0  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
# 1  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
# 2  {'author': {'name': 'cfmago', 'email': 'cfm.ag...
#
#                                                  url  \
# 0  https://api.github.com/repos/cfmago/lab-numpy/...
# 1  https://api.github.com/repos/cfmago/lab-numpy/...
# 2  https://api.github.com/repos/cfmago/lab-numpy/...
#
#                                             html_url  \
# 0  https://github.com/cfmago/lab-numpy/commit/0b0...
# ...

# %%
response = pd.json_normalize(response.json())
response
# Out:
#                                         sha  \
# 0  0b0b90ef6e88e7b5983a44abc9a79f272bc763cb
# 1  12edeef77ab7a9fe77ff94abc6ae0b35537a8d4f
# 2  b659318669c0d35668945c240433e313128db1cd
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjY0OjBiMGI5MGVmNmU4OGU3Yj...
# 1  MDY6Q29tbWl0Mjc2NjIwNjY0OjEyZWRlZWY3N2FiN2E5Zm...
# 2  MDY6Q29tbWl0Mjc2NjIwNjY0OmI2NTkzMTg2NjljMGQzNT...
#
#                                                  url  \
# 0  https://api.github.com/repos/cfmago/lab-numpy/...
# 1  https://api.github.com/repos/cfmago/lab-numpy/...
# 2  https://api.github.com/repos/cfmago/lab-numpy/...
#
#                                             html_url  \
# 0  https://github.com/cfmago/lab-numpy/commit/0b0...
# 1  https://github.com/cfmago/lab-numpy/commit/12e...
# 2  https://github.com/cfmago/lab-numpy/commit/b65...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/cfmago/lab-numpy/...
# ...

# %%
response.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
response['commit.committer.date']
# Out:
# 0    2020-07-04T09:24:27Z
# 1    2020-07-03T10:26:56Z
# 2    2020-07-02T12:13:18Z
# Name: commit.committer.date, dtype: object

# %%
response['commit.committer.date'].count()

#There were 3 commits in the last three weeks
# Out:
# 3
