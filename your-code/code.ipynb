# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

from requests.auth import HTTPBasicAuth

url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018"

rs = requests.get(url, auth=HTTPBasicAuth('fredericomcorda', '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'))
rs.json()
# Out:
# {'id': 153720804,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=',
#  'name': 'mad-oct-2018',
#  'full_name': 'ironhack-datalabs/mad-oct-2018',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
rs = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks')
total_forks_json = rs.json()

# %%
language = pd.json_normalize(total_forks_json)['language'].unique()
print(language)
# Out:
# [None 'Jupyter Notebook' 'HTML']

# %%
url = "https://api.github.com/repos/fredericomcorda/lab-list-comprehensions"

rs = requests.get(url, auth=HTTPBasicAuth('fredericomcorda', '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'))
rs.json()['commits_url']
# Out:
# 'https://api.github.com/repos/fredericomcorda/lab-list-comprehensions/commits{/sha}'

# %%
url = "https://api.github.com/repos/fredericomcorda/lab-list-comprehensions/commits"

rs = requests.get(url, auth=HTTPBasicAuth('fredericomcorda', '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'))

count_commits_df = pd.json_normalize(rs.json())

count_commits_df
# Out:
#                                         sha  \
# 0  47377ed34583b1e56f9227005442a38e3b39cedb
# 1  b759c5d4ac92a378d9f0a2b6caac1b80dd5c0ae2
# 2  1030e8baa965c6bf2e3a5b9545c506f18b8e0fe9
# 3  8949a53afaeae22f5ce7eba669b73c4479c93542
# 4  5621b3256668f9a15172d79124be70933faba2d9
# 5  80d757c463929428fcc3257b8f48d811a66dc6cc
#
#                                              node_id  \
# 0  C_kwDOH-QvOtoAKDQ3Mzc3ZWQzNDU4M2IxZTU2ZjkyMjcw...
# 1  C_kwDOH-QvOtoAKGI3NTljNWQ0YWM5MmEzNzhkOWYwYTJi...
# 2  C_kwDOH-QvOtoAKDEwMzBlOGJhYTk2NWM2YmYyZTNhNWI5...
# 3  MDY6Q29tbWl0NTM1MDQ3OTk0Ojg5NDlhNTNhZmFlYWUyMm...
# 4  MDY6Q29tbWl0NTM1MDQ3OTk0OjU2MjFiMzI1NjY2OGY5YT...
# 5  MDY6Q29tbWl0NTM1MDQ3OTk0OjgwZDc1N2M0NjM5Mjk0Mj...
#
#                                                  url  \
# 0  https://api.github.com/repos/fredericomcorda/l...
# 1  https://api.github.com/repos/fredericomcorda/l...
# 2  https://api.github.com/repos/fredericomcorda/l...
# 3  https://api.github.com/repos/fredericomcorda/l...
# ...

# %%
count_commits_df['commit.author.date'] =  pd.to_datetime(count_commits_df['commit.author.date'])

# %%
from datetime import datetime, timedelta

count_commits_df[count_commits_df['commit.author.date'] > (datetime.today() - timedelta(days=14)).strftime("%d-%m-%Y")]
#there are 0 commits in the last 14 days, 2 wks
# Out:
# Empty DataFrame
# ...
