# %% [markdown]
# ### Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is `ironhack-datalabs/datalis0819`, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 1. Loop the JSON response to find out the `language` attribute of each fork. Use an array to store the `language` attributes of each fork.
#     * *Hint: Each language should appear only once in your array.*
#
# 1. Print the language array. It should be something like:
#
# 	```["Python", "Jupyter Notebook", "HTML"]```
#
# Again, the documentation of Github API is [here](https://developer.github.com/v3/).

# %%
# Importing libraries

import pandas as pd
import requests
import json
import numpy as np

# %%
# Assign page URL to a variable
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

# get method from requests

response = requests.get(url,auth=('laurawuerz','7053b1a8a3cc00d6b5dd812d8845729b64fe98ef'))#.json()

response.text
# Out:
# '[{"id":204513290,"node_id":"MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=","name":"datalis0819","full_name":"Inrx/datalis0819","private":false,"owner":{"login":"Inrx","id":49349821,"node_id":"MDQ6VXNlcjQ5MzQ5ODIx","avatar_url":"https://avatars2.githubusercontent.com/u/49349821?v=4","gravatar_id":"","url":"https://api.github.com/users/Inrx","html_url":"https://github.com/Inrx","followers_url":"https://api.github.com/users/Inrx/followers","following_url":"https://api.github.com/users/Inrx/following{/other_user}","gists_url":"https://api.github.com/users/Inrx/gists{/gist_id}","starred_url":"https://api.github.com/users/Inrx/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Inrx/subscriptions","organizations_url":"https://api.github.com/users/Inrx/orgs","repos_url":"https://api.github.com/users/Inrx/repos","events_url":"https://api.github.com/users/Inrx/events{/privacy}","received_events_url":"https://api.github.com/users/Inrx/received_events","type":"User","site_admin":false},"html_url":"https://github.com/Inrx/datalis0819","description":"Data Analytics Full Time Lisbon, August 2019","fork":true,"url":"https://api.github.com/repos/Inrx/datalis0819","forks_url":"https://api.github.com/repos/Inrx/datalis0819/forks","keys_url":"https://api.github.com/repos/Inrx/datalis0819/keys{/key_id}","collaborators_url":"https://api.github.com/repos/Inrx/datalis0819/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/Inrx/datalis0819/teams","hooks_url":"https://api.github.com/repos/Inrx/datalis0819/hooks","issue_events_url":"https://api.github.com/repos/Inrx/datalis0819/issues/events{/number}","events_url":"https://api.github.com/repos/Inrx/datalis0819/events","assignees_url":"https://api.github.com/repos/Inrx/datalis0819/assignees{/user}","branches_url":"https://api.github.com/repos/Inrx/datalis0819/branches{/branch}","tags_url":"https://api.github.com/repos/Inrx/datalis0819/tags","blobs_url":"https://api.github.com/repos/Inrx/datalis0819/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/Inrx/datalis0819/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/Inrx/datalis0819/git/refs{/sha}","trees_url":"https://api.github.com/repos/Inrx/datalis0819/git/trees{/sha}","statuses_url":"https://api.github.com/repos/Inrx/datalis0819/statuses/{sha}","languages_url":"https://api.github.com/repos/Inrx/datalis0819/languages","stargazers_url":"https://api.github.com/repos/Inrx/datalis0819/stargazers","contributors_url":"https://api.github.com/repos/Inrx/datalis0819/contributors","subscribers_url":"https://api.github.com/repos/Inrx/datalis0819/subscribers","subscription_url":"https://api.github.com/repos/Inrx/datalis0819/subscription","commits_url":"https://api.github.com/repos/Inrx/datalis0819/commits{/sha}","git_commits_url":"https://api.github.com/repos/Inrx/datalis0819/git/commits{/sha}","comments_url":"https://api.github.com/repos/Inrx/datalis0819/comments{/number}","issue_comment_url":"https://api.github.com/repos/Inrx/datalis0819/issues/comments{/number}","contents_url":"https://api.github.com/repos/Inrx/datalis0819/contents/{+path}","compare_url":"https://api.github.com/repos/Inrx/datalis0819/compare/{base}...{head}","merges_url":"https://api.github.com/repos/Inrx/datalis0819/merges","archive_url":"https://api.github.com/repos/Inrx/datalis0819/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/Inrx/datalis0819/downloads","issues_url":"https://api.github.com/repos/Inrx/datalis0819/issues{/number}","pulls_url":"https://api.github.com/repos/Inrx/datalis0819/pulls{/number}","milestones_url":"https://api.github.com/repos/Inrx/datalis0819/milestones{/number}","notifications_url":"https://api.github.com/repos/Inrx/datalis0819/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/Inrx/datalis0819/labels{/name}","releases_url":"https://api.github.com/repos/Inrx/datalis0819/releases{/id}","deployments_url":"https://api.github.com/repos/Inrx/datalis0819/deploymen ...

# %%
# Create dataframe

df = pd.DataFrame(response.json())

df.head()
# Out:
#           id                           node_id         name  \
# 0  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 1  202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 2  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 3  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 4  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
#
#                      full_name  private  \
# 0             Inrx/datalis0819    False
# 1       laurawuerz/datalis0819    False
# 2  filipamiralopes/datalis0819    False
# 3      janpotthoff/datalis0819    False
# 4      sofia-sousa/datalis0819    False
#
#                                                owner  \
# 0  {'login': 'Inrx', 'id': 49349821, 'node_id': '...
# 1  {'login': 'laurawuerz', 'id': 52656811, 'node_...
# 2  {'login': 'filipamiralopes', 'id': 42877871, '...
# 3  {'login': 'janpotthoff', 'id': 53485922, 'node...
# 4  {'login': 'sofia-sousa', 'id': 53151504, 'node...
#
#                                          html_url  \
# 0             https://github.com/Inrx/datalis0819
# 1       https://github.com/laurawuerz/datalis0819
# 2  https://github.com/filipamiralopes/datalis0819
# 3      https://github.com/janpotthoff/datalis0819
# 4      https://github.com/sofia-sousa/datalis0819
#
#                                     description  fork  \
# 0  Data Analytics Full Time Lisbon, August 2019  True
# 1  Data Analytics Full Time Lisbon, August 2019  True
# 2  Data Analytics Full Time Lisbon, August 2019  True
# 3  Data Analytics Full Time Lisbon, August 2019  True
# 4  Data Analytics Full Time Lisbon, August 2019  True
#
#                                                  url  ... mirror_url archived  \
# 0      https://api.github.com/repos/Inrx/datalis0819  ...       None    False
# 1  https://api.github.com/repos/laurawuerz/datali...  ...       None    False
# 2  https://api.github.com/repos/filipamiralopes/d...  ...       None    False
# 3  https://api.github.com/repos/janpotthoff/datal...  ...       None    False
# 4  https://api.github.com/repos/sofia-sousa/datal...  ...       None    False
#
#   disabled open_issues_count  \
# 0    False                 0
# 1    False                 0
# 2    False                 0
# 3    False                 0
# 4    False                 0
#
#                                              license forks open_issues  \
# 0  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 1  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 2  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 3  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 4  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
#
#   watchers default_branch                                    permissions
# 0        0         master  {'admin': False, 'push': False, 'pull': True}
# 1        0         master    {'admin': True, 'push': True, 'pull': True}
# 2        0         master  {'admin': False, 'push': False, 'pull': True}
# 3        0         master  {'admin': False, 'push': False, 'pull': True}
# 4        0         master  {'admin': False, 'push': False, 'pull': True}
#
# [5 rows x 74 columns]

# %%
df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license',
#        'forks', 'open_issues', 'watchers', 'default_branch', 'permissions'],
#       dtype='object')

# %%
df_forks = df[['name','fork','forks_count','forks','language']]
df_forks
# Out:
#            name  fork  forks_count  forks          language
# 0   datalis0819  True            0      0  Jupyter Notebook
# 1   datalis0819  True            0      0  Jupyter Notebook
# 2   datalis0819  True            0      0  Jupyter Notebook
# 3   datalis0819  True            0      0  Jupyter Notebook
# 4   datalis0819  True            0      0  Jupyter Notebook
# 5   datalis0819  True            0      0  Jupyter Notebook
# 6   datalis0819  True            0      0  Jupyter Notebook
# 7   datalis0819  True            0      0  Jupyter Notebook
# 8         data2  True            0      0  Jupyter Notebook
# 9   datalis0819  True            0      0  Jupyter Notebook
# 10  datalis0819  True            0      0  Jupyter Notebook

# %%
df_forks.shape
# Out:
# (11, 5)

# %%
df_forks['language'].unique().tolist()
# Out:
# ['Jupyter Notebook']

# %% [markdown]
# ### Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
# 1. Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# 1. Count how many commit objects are contained in the array.

# %%
# Assign page URL to a variable
url2 = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/commits'

# get method from requests

response2 = requests.get(url2,auth=('laurawuerz','7053b1a8a3cc00d6b5dd812d8845729b64fe98ef')).json()

df_commit = pd.DataFrame(response2)



print(df_commit.columns)
print(df_commit.shape)
df_commit.head()
# Out:
# Index(['sha', 'node_id', 'commit', 'url', 'html_url', 'comments_url', 'author',
#        'committer', 'parents'],
#       dtype='object')
# (30, 9)
#                                         sha  \
# 0  abebdae9e9f22a43419ae23520e93fafbce5a238
# 1  9f8892572f69b657afc2c1d8fc86feaa26a854fc
# 2  dad154e138221514f3a307a02992afe6a4da7d22
# 3  d4111da8c59075a6250742b26f8ffcf11062a594
# 4  ec14215572a45a8c241c8b9fb3622c66810872f6
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MTk4NjQ3MjIyOmFiZWJkYWU5ZTlmMjJhND...
# 1  MDY6Q29tbWl0MTk4NjQ3MjIyOjlmODg5MjU3MmY2OWI2NT...
# 2  MDY6Q29tbWl0MTk4NjQ3MjIyOmRhZDE1NGUxMzgyMjE1MT...
# 3  MDY6Q29tbWl0MTk4NjQ3MjIyOmQ0MTExZGE4YzU5MDc1YT...
# 4  MDY6Q29tbWl0MTk4NjQ3MjIyOmVjMTQyMTU1NzJhNDVhOG...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carlos Madriz', 'email': ...
# 4  {'author': {'name': 'Carlos Madriz', 'email': ...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datalis08...
# 1  https://github.com/ironhack-datalabs/datalis08...
# 2  https://github.com/ironhack-datalabs/datalis08...
# 3  https://github.com/ironhack-datalabs/datalis08...
# 4  https://github.com/ironhack-datalabs/datalis08...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                               author  \
# 0  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 1  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 2  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 3  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 4  {'login': 'carlosmd14', 'id': 45972288, 'node_...
#
#                                            committer  \
# 0  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 1  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 2  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 3  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 4  {'login': 'web-flow', 'id': 19864447, 'node_id...
#
#                                              parents
# 0  [{'sha': '9f8892572f69b657afc2c1d8fc86feaa26a8...
# 1  [{'sha': 'dad154e138221514f3a307a02992afe6a4da...
# 2  [{'sha': 'd4111da8c59075a6250742b26f8ffcf11062...
# 3  [{'sha': 'ec14215572a45a8c241c8b9fb3622c668108...
# 4  [{'sha': 'f343d176f35b4b545c858c1a9d5db8bab788...

# %%
from pandas.io.json import json_normalize 

 
norm_json = json_normalize(response2) 

ds_normalized = pd.DataFrame(norm_json) 

ds_normalized.head(10)
# Out:
#                                         sha  \
# 0  abebdae9e9f22a43419ae23520e93fafbce5a238
# 1  9f8892572f69b657afc2c1d8fc86feaa26a854fc
# 2  dad154e138221514f3a307a02992afe6a4da7d22
# 3  d4111da8c59075a6250742b26f8ffcf11062a594
# 4  ec14215572a45a8c241c8b9fb3622c66810872f6
# 5  f343d176f35b4b545c858c1a9d5db8bab788a7eb
# 6  a83168ce17558c88e7599d382125672d66315167
# 7  f0729d44ad197232873bf77c3bee76ce5a207661
# 8  f67d9f87ee9de4902f62cd8739e52db9d5d41614
# 9  7551ef430c03048f790eb895830f04fd80f57d43
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MTk4NjQ3MjIyOmFiZWJkYWU5ZTlmMjJhND...
# 1  MDY6Q29tbWl0MTk4NjQ3MjIyOjlmODg5MjU3MmY2OWI2NT...
# 2  MDY6Q29tbWl0MTk4NjQ3MjIyOmRhZDE1NGUxMzgyMjE1MT...
# 3  MDY6Q29tbWl0MTk4NjQ3MjIyOmQ0MTExZGE4YzU5MDc1YT...
# 4  MDY6Q29tbWl0MTk4NjQ3MjIyOmVjMTQyMTU1NzJhNDVhOG...
# 5  MDY6Q29tbWl0MTk4NjQ3MjIyOmYzNDNkMTc2ZjM1YjRiNT...
# 6  MDY6Q29tbWl0MTk4NjQ3MjIyOmE4MzE2OGNlMTc1NThjOD...
# 7  MDY6Q29tbWl0MTk4NjQ3MjIyOmYwNzI5ZDQ0YWQxOTcyMz...
# 8  MDY6Q29tbWl0MTk4NjQ3MjIyOmY2N2Q5Zjg3ZWU5ZGU0OT...
# 9  MDY6Q29tbWl0MTk4NjQ3MjIyOjc1NTFlZjQzMGMwMzA0OG...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
# 5  https://api.github.com/repos/ironhack-datalabs...
# 6  https://api.github.com/repos/ironhack-datalabs...
# 7  https://api.github.com/repos/ironhack-datalabs...
# 8  https://api.github.com/repos/ironhack-datalabs...
# 9  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datalis08...
# 1  https://github.com/ironhack-datalabs/datalis08...
# 2  https://github.com/ironhack-datalabs/datalis08...
# 3  https://github.com/ironhack-datalabs/datalis08...
# 4  https://github.com/ironhack-datalabs/datalis08...
# 5  https://github.com/ironhack-datalabs/datalis08...
# 6  https://github.com/ironhack-datalabs/datalis08...
# 7  https://github.com/ironhack-datalabs/datalis08...
# 8  https://github.com/ironhack-datalabs/datalis08...
# 9  https://github.com/ironhack-datalabs/datalis08...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
# 5  https://api.github.com/repos/ironhack-datalabs...
# 6  https://api.github.com/repos/ironhack-datalabs...
# 7  https://api.github.com/repos/ironhack-datalabs...
# 8  https://api.github.com/repos/ironhack-datalabs...
# 9  https://api.github.com/repos/ironhack-datalabs...
#
#                                              parents commit.author.name  \
# 0  [{'sha': '9f8892572f69b657afc2c1d8fc86feaa26a8...      Carlos Madriz
# 1  [{'sha': 'dad154e138221514f3a307a02992afe6a4da...      Carlos Madriz
# 2  [{'sha': 'd4111da8c59075a6250742b26f8ffcf11062...      Carlos Madriz
# 3  [{'sha': 'ec14215572a45a8c241c8b9fb3622c668108...      Carlos Madriz
# 4  [{'sha': 'f343d176f35b4b545c858c1a9d5db8bab788...      Carlos Madriz
# 5  [{'sha': 'a83168ce17558c88e7599d382125672d6631...      Carlos Madriz
# 6  [{'sha': 'f0729d44ad197232873bf77c3bee76ce5a20...      Carlos Madriz
# 7  [{'sha': 'f67d9f87ee9de4902f62cd8739e52db9d5d4...      Carlos Madriz
# 8  [{'sha': '7551ef430c03048f790eb895830f04fd80f5...      Carlos Madriz
# 9  [{'sha': 'd1260e3735127901c448ba7375f9b93cdf41...      Carlos Madriz
#
#                             commit.author.email    commit.author.date  \
# 0  45972288+carlosmd14@users.noreply.github.com  2019-08-14T10:31:56Z
# 1  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:46:30Z
# 2  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:43:52Z
# 3  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:43:45Z
# 4  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:43:39Z
# 5  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:42:05Z
# 6  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:41:58Z
# 7  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:41:51Z
# 8  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:41:41Z
# 9  45972288+carlosmd14@users.noreply.github.com  2019-08-13T07:41:31Z
#
#   commit.committer.name  ...  \
# 0                GitHub  ...
# 1                GitHub  ...
# 2                GitHub  ...
# 3                GitHub  ...
# 4                GitHub  ...
# 5                GitHub  ...
# 6                GitHub  ...
# 7                GitHub  ...
# 8                GitHub  ...
# 9                GitHub  ...
#
#                              committer.following_url  \
# 0  https://api.github.com/users/web-flow/followin...
# 1  https://api.github.com/users/web-flow/followin...
# 2  https://api.github.com/users/web-flow/followin...
# 3  https://api.github.com/users/web-flow/followin...
# 4  https://api.github.com/users/web-flow/followin...
# 5  https://api.github.com/users/web-flow/followin...
# 6  https://api.github.com/users/web-flow/followin...
# 7  https://api.github.com/users/web-flow/followin...
# 8  https://api.github.com/users/web-flow/followin...
# 9  https://api.github.com/users/web-flow/followin...
#
#                                  committer.gists_url  \
# 0  https://api.github.com/users/web-flow/gists{/g...
# 1  https://api.github.com/users/web-flow/gists{/g...
# 2  https://api.github.com/users/web-flow/gists{/g...
# 3  https://api.github.com/users/web-flow/gists{/g...
# 4  https://api.github.com/users/web-flow/gists{/g...
# 5  https://api.github.com/users/web-flow/gists{/g...
# 6  https://api.github.com/users/web-flow/gists{/g...
# 7  https://api.github.com/users/web-flow/gists{/g...
# 8  https://api.github.com/users/web-flow/gists{/g...
# 9  https://api.github.com/users/web-flow/gists{/g...
#
#                                committer.starred_url  \
# 0  https://api.github.com/users/web-flow/starred{...
# 1  https://api.github.com/users/web-flow/starred{...
# 2  https://api.github.com/users/web-flow/starred{...
# 3  https://api.github.com/users/web-flow/starred{...
# 4  https://api.github.com/users/web-flow/starred{...
# 5  https://api.github.com/users/web-flow/starred{...
# 6  https://api.github.com/users/web-flow/starred{...
# 7  https://api.github.com/users/web-flow/starred{...
# 8  https://api.github.com/users/web-flow/starred{...
# 9  https://api.github.com/users/web-flow/starred{...
#
#                          committer.subscriptions_url  \
# 0  https://api.github.com/users/web-flow/subscrip...
# 1  https://api.github.com/users/web-flow/subscrip...
# 2  https://api.github.com/users/web-flow/subscrip...
# 3  https://api.github.com/users/web-flow/subscrip...
# 4  https://api.github.com/users/web-flow/subscrip...
# 5  https://api.github.com/users/web-flow/subscrip...
# 6  https://api.github.com/users/web-flow/subscrip...
# 7  https://api.github.com/users/web-flow/subscrip...
# 8  https://api.github.com/users/web-flow/subscrip...
# 9  https://api.github.com/users/web-flow/subscrip...
#
#                   committer.organizations_url  \
# 0  https://api.github.com/users/web-flow/orgs
# 1  https://api.github.com/users/web-flow/orgs
# 2  https://api.github.com/users/web-flow/orgs
# 3  https://api.github.com/users/web-flow/orgs
# 4  https://api.github.com/users/web-flow/orgs
# 5  https://api.github.com/users/web-flow/orgs
# 6  https://api.github.com/users/web-flow/orgs
# 7  https://api.github.com/users/web-flow/orgs
# 8  https://api.github.com/users/web-flow/orgs
# 9  https://api.github.com/users/web-flow/orgs
#
#                            committer.repos_url  \
# 0  https://api.github.com/users/web-flow/repos
# 1  https://api.github.com/users/web-flow/repos
# 2  https://api.github.com/users/web-flow/repos
# 3  https://api.github.com/users/web-flow/repos
# 4  https://api.github.com/users/web-flow/repos
# 5  https://api.github.com/users/web-flow/repos
# 6  https://api.github.com/users/web-flow/repos
# 7  https://api.github.com/users/web-flow/repos
# 8  https://api.github.com/users/web-flow/repos
# 9  https://api.github.com/users/web-flow/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/web-flow/events{/...
# 1  https://api.github.com/users/web-flow/events{/...
# 2  https://api.github.com/users/web-flow/events{/...
# 3  https://api.github.com/users/web-flow/events{/...
# 4  https://api.github.com/users/web-flow/events{/...
# 5  https://api.github.com/users/web-flow/events{/...
# 6  https://api.github.com/users/web-flow/events{/...
# 7  https://api.github.com/users/web-flow/events{/...
# 8  https://api.github.com/users/web-flow/events{/...
# 9  https://api.github.com/users/web-flow/events{/...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/web-flow/received...           User
# 1  https://api.github.com/users/web-flow/received...           User
# 2  https://api.github.com/users/web-flow/received...           User
# 3  https://api.github.com/users/web-flow/received...           User
# 4  https://api.github.com/users/web-flow/received...           User
# 5  https://api.github.com/users/web-flow/received...           User
# 6  https://api.github.com/users/web-flow/received...           User
# 7  https://api.github.com/users/web-flow/received...           User
# 8  https://api.github.com/users/web-flow/received...           User
# 9  https://api.github.com/users/web-flow/received...           User
#
#   committer.site_admin
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
#
# [10 rows x 57 columns]

# %%
df_commit = ds_normalized[['url','commit.author.name','commit.author.date']]

# %%
df_commit['commit.author.date'] = pd.to_datetime(df_commit['commit.author.date']).dt.date
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_commit.head()
# Out:
#                                                  url commit.author.name  \
# 0  https://api.github.com/repos/ironhack-datalabs...      Carlos Madriz
# 1  https://api.github.com/repos/ironhack-datalabs...      Carlos Madriz
# 2  https://api.github.com/repos/ironhack-datalabs...      Carlos Madriz
# 3  https://api.github.com/repos/ironhack-datalabs...      Carlos Madriz
# 4  https://api.github.com/repos/ironhack-datalabs...      Carlos Madriz
#
#   commit.author.date
# 0         2019-08-14
# 1         2019-08-13
# 2         2019-08-13
# 3         2019-08-13
# 4         2019-08-13

# %%
df_commit['commit.author.date'] = pd.to_datetime(df_commit['commit.author.date'])
date_start = '2019-08-19'
mask = (df_commit['commit.author.date'] > date_start) 
df_commit_week = df_commit.loc[mask]
df_commit_week
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [url, commit.author.name, commit.author.date]
# Index: []

# %%
df_commit_week['commit.author.date'].unique().tolist()
# Out:
# []

# %% [markdown]
# ### Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain `.scavengerhunt` and they are scattered in different directories of this repo. The secret files are named from `.0001.scavengerhunt` to `.0024.scavengerhunt`. They are scattered randomly throughout this repo. You need to **search for these files by calling the Github API**, not searching the local files on your computer.
#
# Notes:
#
# * Github API documentation can be found [here](https://developer.github.com/v3/).
#
# * You will need to study the Github API documentation to decide which API endpoint to call and what parameters to use in order to obtain the information you need. Unless you are already super familiar with Github API or super lucky, you probably will do some trials and errors. Therefore, be prepared to go back and forth in studying the API documentation, testing, and revising until you obtain what you need.
#
# * After receiving the JSON data object, you need to inspect its structure and decide how to parse the data.
#
# * When you test your requests with Github API, sometimes you may be blocked by Github with an error message that reads:
#
# 	> You have triggered an abuse detection mechanism and have been temporarily blocked from content creation. Please retry your request again later.
#
# 	Don't worry. Check the parameters in your request and wait for a minute or two before you make additional requests.
#
# **After you find out the secrete files:**
#
# 1. Sort the filenames ascendingly.
#
# 1. Read the content of each secret files into an array of strings.
#
# 1. Concatenate the strings in the array separating each two with a whitespace.
#
# 1. Print out the joke.

# %%
# Assign page URL to a variable
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger'

# get method from requests

response_2 = requests.get(url,auth=('laurawuerz','7053b1a8a3cc00d6b5dd812d8845729b64fe98ef'))#.json()

response_2.text
# Out:
# '{"id":162375181,"node_id":"MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=","name":"scavenger","full_name":"ironhack-datalabs/scavenger","private":false,"owner":{"login":"ironhack-datalabs","id":44225188,"node_id":"MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4","avatar_url":"https://avatars2.githubusercontent.com/u/44225188?v=4","gravatar_id":"","url":"https://api.github.com/users/ironhack-datalabs","html_url":"https://github.com/ironhack-datalabs","followers_url":"https://api.github.com/users/ironhack-datalabs/followers","following_url":"https://api.github.com/users/ironhack-datalabs/following{/other_user}","gists_url":"https://api.github.com/users/ironhack-datalabs/gists{/gist_id}","starred_url":"https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ironhack-datalabs/subscriptions","organizations_url":"https://api.github.com/users/ironhack-datalabs/orgs","repos_url":"https://api.github.com/users/ironhack-datalabs/repos","events_url":"https://api.github.com/users/ironhack-datalabs/events{/privacy}","received_events_url":"https://api.github.com/users/ironhack-datalabs/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/ironhack-datalabs/scavenger","description":null,"fork":false,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger","forks_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/forks","keys_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/keys{/key_id}","collaborators_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/teams","hooks_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/hooks","issue_events_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/issues/events{/number}","events_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/events","assignees_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}","branches_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}","tags_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/tags","blobs_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/refs{/sha}","trees_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees{/sha}","statuses_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/statuses/{sha}","languages_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/languages","stargazers_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/stargazers","contributors_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contributors","subscribers_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/subscribers","subscription_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/subscription","commits_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/commits{/sha}","git_commits_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits{/sha}","comments_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/comments{/number}","issue_comment_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/issues/comments{/number}","contents_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{+path}","compare_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/compare/{base}...{head}","merges_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/merges","archive_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/downloads","issues_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/issues{/number}" ...

# %%
# Create dataframe

df_2 = pd.DataFrame(response_2.json())

df_2.head()
# Out:
#                     id                           node_id       name  \
# login        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# id           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# node_id      162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# avatar_url   162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gravatar_id  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
#
#                                full_name  private  \
# login        ironhack-datalabs/scavenger    False
# id           ironhack-datalabs/scavenger    False
# node_id      ironhack-datalabs/scavenger    False
# avatar_url   ironhack-datalabs/scavenger    False
# gravatar_id  ironhack-datalabs/scavenger    False
#
#                                                          owner  \
# login                                        ironhack-datalabs
# id                                                    44225188
# node_id                       MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4
# avatar_url   https://avatars2.githubusercontent.com/u/44225...
# gravatar_id
#
#                                                    html_url description  \
# login        https://github.com/ironhack-datalabs/scavenger        None
# id           https://github.com/ironhack-datalabs/scavenger        None
# node_id      https://github.com/ironhack-datalabs/scavenger        None
# avatar_url   https://github.com/ironhack-datalabs/scavenger        None
# gravatar_id  https://github.com/ironhack-datalabs/scavenger        None
#
#               fork                                                url  ...  \
# login        False  https://api.github.com/repos/ironhack-datalabs...  ...
# id           False  https://api.github.com/repos/ironhack-datalabs...  ...
# node_id      False  https://api.github.com/repos/ironhack-datalabs...  ...
# avatar_url   False  https://api.github.com/repos/ironhack-datalabs...  ...
# gravatar_id  False  https://api.github.com/repos/ironhack-datalabs...  ...
#
#             open_issues_count license forks open_issues watchers  \
# login                       0    None     4           0        0
# id                          0    None     4           0        0
# node_id                     0    None     4           0        0
# avatar_url                  0    None     4           0        0
# gravatar_id                 0    None     4           0        0
#
#             default_branch permissions  \
# login               master         NaN
# id                  master         NaN
# node_id             master         NaN
# avatar_url          master         NaN
# gravatar_id         master         NaN
#
#                                                   organization network_count  \
# login                                        ironhack-datalabs             4
# id                                                    44225188             4
# node_id                       MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4             4
# avatar_url   https://avatars2.githubusercontent.com/u/44225...             4
# gravatar_id                                                                4
#
#             subscribers_count
# login                       2
# id                          2
# node_id                     2
# avatar_url                  2
# gravatar_id                 2
#
# [5 rows x 77 columns]

# %%
df_2.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license',
#        'forks', 'open_issues', 'watchers', 'default_branch', 'permissions',
#        'organization', 'network_count', 'subscribers_count'],
#       dtype='object')

# %%
df_scavenger = df_2.filter(like='.scavengerhunt').values

# %%
df_scavenger
# Out:
# array([], shape=(21, 0), dtype=float64)

# %%
df_scavenger.isin(['scavengerhunt']).any()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-b5a6226ff342> in <module>
# ----> 1 df_scavenger.isin(['scavengerhunt']).any()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isin'
