# %%
# CHALLENGE 1

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/datalis0819/forks')

# %%
response
# Out:
# <Response [200]>

# %%
response.headers
# Out:
# {'Date': 'Mon, 04 Nov 2019 16:01:20 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Server': 'GitHub.com', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '1', 'X-RateLimit-Reset': '1572886478', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding', 'ETag': 'W/"6b3b9cf616066f0f279f7273b7978935"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default
# ...

# %%
response.content
# Out:
# b'[{"id":206122694,"node_id":"MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=","name":"datalis0819","full_name":"ta-data-lis/datalis0819","private":false,"owner":{"login":"ta-data-lis","id":54109907,"node_id":"MDQ6VXNlcjU0MTA5OTA3","avatar_url":"https://avatars0.githubusercontent.com/u/54109907?v=4","gravatar_id":"","url":"https://api.github.com/users/ta-data-lis","html_url":"https://github.com/ta-data-lis","followers_url":"https://api.github.com/users/ta-data-lis/followers","following_url":"https://api.github.com/users/ta-data-lis/following{/other_user}","gists_url":"https://api.github.com/users/ta-data-lis/gists{/gist_id}","starred_url":"https://api.github.com/users/ta-data-lis/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ta-data-lis/subscriptions","organizations_url":"https://api.github.com/users/ta-data-lis/orgs","repos_url":"https://api.github.com/users/ta-data-lis/repos","events_url":"https://api.github.com/users/ta-data-lis/events{/privacy}","received_events_url"
# ...

# %%
df=pd.DataFrame(response.json())
df
# Out:
#            id                           node_id         name  \
# 0   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 1   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 2   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 3   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 4   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 5   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 6   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 7   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 8   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 9   199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 10  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 11  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# 0       ta-data-lis/datalis0819    False
# 1              Inrx/datalis0819    False
# 2        laurawuerz/datalis0819    False
# ...

# %%
norm_forks = json_normalize(response.json())
df_norm = pd.DataFrame(norm_forks)
df_norm
# Out:
#            id                           node_id         name  \
# 0   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 1   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 2   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 3   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 4   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 5   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 6   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 7   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 8   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 9   199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 10  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 11  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# 0       ta-data-lis/datalis0819    False
# 1              Inrx/datalis0819    False
# 2        laurawuerz/datalis0819    False
# ...

# %%
df_norm.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
df_norm["language"]
# Out:
# 0     Jupyter Notebook
# 1     Jupyter Notebook
# 2     Jupyter Notebook
# 3     Jupyter Notebook
# 4     Jupyter Notebook
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10    Jupyter Notebook
# 11    Jupyter Notebook
# Name: language, dtype: object
