# %%
import requests
import json 
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datalis0819/forks"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# [{'id': 219552641,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=',
#   'name': 'datalis0819',
#   'full_name': 'Mariana427/datalis0819',
#   'private': False,
#   'owner': {'login': 'Mariana427',
#    'id': 54869432,
#    'node_id': 'MDQ6VXNlcjU0ODY5NDMy',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/54869432?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mariana427',
#    'html_url': 'https://github.com/Mariana427',
#    'followers_url': 'https://api.github.com/users/Mariana427/followers',
#    'following_url': 'https://api.github.com/users/Mariana427/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Mariana427/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Mariana427/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Mariana427/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Mariana427/orgs',
# ...

# %%
# searching data for "language" attribute
forks = pd.DataFrame(result)
forks
# Out:
#            id                           node_id         name  \
# 0   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 13  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# ...

# %%
norm_forks = json_normalize(result)
norm_forks
# Out:
#            id                           node_id         name  \
# 0   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 13  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# ...

# %%
df = pd.DataFrame(norm_forks)
df
# Out:
#            id                           node_id         name  \
# 0   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 13  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# ...

# %%
languages = df["language"]

# %%
languages= list(languages.drop_duplicates())
languages
# Out:
# [None, 'Jupyter Notebook']
