# %%
import pandas as pd
import requests
import json

# %%
url = "https://api.github.com/user"
access_token='0e8341b5d6daac68c985573f03216d5ab79a0b9a' 
headers = {'Authorization':"Token "+access_token}

# %%
# This will prompt you for a password
repo=requests.get(url,headers=headers)
print(repo.status_code)
repo.json()
# Out:
# 200
# {'login': 'R04425',
#  'id': 72349906,
#  'node_id': 'MDQ6VXNlcjcyMzQ5OTA2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/72349906?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/R04425',
#  'html_url': 'https://github.com/R04425',
#  'followers_url': 'https://api.github.com/users/R04425/followers',
#  'following_url': 'https://api.github.com/users/R04425/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/R04425/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/R04425/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/R04425/subscriptions',
#  'organizations_url': 'https://api.github.com/users/R04425/orgs',
#  'repos_url': 'https://api.github.com/users/R04425/repos',
#  'events_url': 'https://api.github.com/users/R04425/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/R04425/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': None,
# ...

# %%
# Get all the repos:
# This will prompt you for a password

url = repo.json()['repos_url']
repo=requests.get(url,headers=headers)
print(repo.status_code)
repo.json()
# Out:
# 200
# [{'id': 313781021,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTM3ODEwMjE=',
#   'name': '2nd-Project-Python-SQL',
#   'full_name': 'R04425/2nd-Project-Python-SQL',
#   'private': False,
#   'owner': {'login': 'R04425',
#    'id': 72349906,
#    'node_id': 'MDQ6VXNlcjcyMzQ5OTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72349906?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/R04425',
#    'html_url': 'https://github.com/R04425',
#    'followers_url': 'https://api.github.com/users/R04425/followers',
#    'following_url': 'https://api.github.com/users/R04425/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/R04425/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/R04425/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/R04425/subscriptions',
#    'organizations_url': 'https://api.github.com/users/R04425/orgs',
#    'repos_url': 'https://api.github.com/users/R04425/repos',
# ...

# %%
# Get the repo:
# This will prompt you for a password

url ='https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks'
repo=requests.get(url,headers=headers)
print(repo.status_code)
repo.json()
# Out:
# 200
# [{'id': 332775885,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3NzU4ODU=',
#   'name': 'bcn-feb-2019',
#   'full_name': 'MRibas123/bcn-feb-2019',
#   'private': False,
#   'owner': {'login': 'MRibas123',
#    'id': 76017312,
#    'node_id': 'MDQ6VXNlcjc2MDE3MzEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76017312?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MRibas123',
#    'html_url': 'https://github.com/MRibas123',
#    'followers_url': 'https://api.github.com/users/MRibas123/followers',
#    'following_url': 'https://api.github.com/users/MRibas123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MRibas123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MRibas123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MRibas123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MRibas123/orgs',
# ...

# %%
df = pd.DataFrame(repo.json())
df.head(10)
# Out:
#           id                           node_id          name  \
# 0  332775885  MDEwOlJlcG9zaXRvcnkzMzI3NzU4ODU=  bcn-feb-2019
# 1  319429421  MDEwOlJlcG9zaXRvcnkzMTk0Mjk0MjE=  bcn-feb-2019
# 2  318578020  MDEwOlJlcG9zaXRvcnkzMTg1NzgwMjA=  bcn-feb-2019
# 3  278336683  MDEwOlJlcG9zaXRvcnkyNzgzMzY2ODM=  bcn-feb-2019
# 4  276718167  MDEwOlJlcG9zaXRvcnkyNzY3MTgxNjc=  bcn-feb-2019
#
#                      full_name  private  \
# 0       MRibas123/bcn-feb-2019    False
# 1  MariaEstebanDA/bcn-feb-2019    False
# 2     je-nakajima/bcn-feb-2019    False
# 3       franbaldi/bcn-feb-2019    False
# 4   brunacarolino/bcn-feb-2019    False
#
#                                                owner  \
# 0  {'login': 'MRibas123', 'id': 76017312, 'node_i...
# 1  {'login': 'MariaEstebanDA', 'id': 72495380, 'n...
# 2  {'login': 'je-nakajima', 'id': 71846807, 'node...
# 3  {'login': 'franbaldi', 'id': 25199469, 'node_i...
# 4  {'login': 'brunacarolino', 'id': 67610079, 'no...
#
# ...

# %%
print(set(df['language']))
# Out:
# {None, 'Jupyter Notebook'}

# %%
## CHALLENGE 2 ###

# %%
response = requests.get('https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits')

# %%
response.json()
# Out:
# [{'sha': '6a243303cfd846faac16417cad54cd40ab3f82c6',
#   'node_id': 'MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2ZmFhYzE2NDE3Y2FkNTRjZDQwYWIzZjgyYzY=',
#   'commit': {'author': {'name': 'Carlos Madriz',
#     'email': '45972288+carlosmd14@users.noreply.github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '5696a145dbbeef9a0417d852b706178bbca30900',
#     'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/trees/5696a145dbbeef9a0417d852b706178bbca30900'},
#    'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/commits/6a243303cfd846faac16417cad54cd40ab3f82c6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
df2 = pd.DataFrame(response.json())
df2.head(10)
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carla Mendes', 'email': '...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
print(len(list(df2['commit'])))
# Out:
# 4

# %%
# Only 4 commits
