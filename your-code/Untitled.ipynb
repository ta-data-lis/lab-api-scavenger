# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from requests.models import HTTPBasicAuth

# %%
response = requests.get("https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks")
lang1 = []
for dit in response.json():
    if dit["language"] not in lang1:
        lang1.append(dit["language"]) 
    else:
        continue
lang1
# Out:
# [None, 'Jupyter Notebook', 'HTML']

# %%
owner = "pedrosnts"
r = requests.get(f"https://api.github.com/repos/{owner}/lab-list-comprehensions")
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'id': 589650379,
#  'node_id': 'R_kgDOIyVZyw',
#  'name': 'lab-list-comprehensions',
#  'full_name': 'pedrosnts/lab-list-comprehensions',
#  'private': False,
#  'owner': {'login': 'pedrosnts',
#   'id': 120747556,
#   'node_id': 'U_kgDOBzJ2JA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/120747556?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pedrosnts',
#   'html_url': 'https://github.com/pedrosnts',
#   'followers_url': 'https://api.github.com/users/pedrosnts/followers',
#   'following_url': 'https://api.github.com/users/pedrosnts/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pedrosnts/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pedrosnts/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pedrosnts/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pedrosnts/orgs',
#   'repos_url': 'https://api.github.com/users/pedrosnts/repos',
# ...

# %%
url = "https://api.github.com/repos/pedrosnts/lab-list-comprehensions/commits"
token = "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"
params = {"since":"2023-01-23"}

r = requests.get(url, params=params, auth=HTTPBasicAuth("pedrosnts",token))

for dicti in r.json():
    print(dicti['commit'])
    
# Zero commits in the for list repo in the last two weeks
