# %%
#CHALLENGE 1

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/languages')

# %%
lang = response.json()

# %%
languages = [lang for lang in lang.keys()]
languages
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
#CHALLENGE 2

# %%
response_2 = requests.get('https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits')

# %%
commit = response_2.json()
commit
# Out:
# [{'sha': '6a243303cfd846faac16417cad54cd40ab3f82c6',
#   'node_id': 'MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2ZmFhYzE2NDE3Y2FkNTRjZDQwYWIzZjgyYzY=',
#   'commit': {'author': {'name': 'Carlos Madriz',
#     'email': '45972288+carlosmd14@users.noreply.github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '5696a145dbbeef9a0417d852b706178bbca30900',
#     'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/trees/5696a145dbbeef9a0417d852b706178bbca30900'},
#    'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/commits/6a243303cfd846faac16417cad54cd40ab3f82c6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
#NEED EXPLANATION

commits = [commit for commit in commit['committer']]
commits
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-6684818b4dec> in <module>
#       1 #NEED EXPLANATION
#       2
# ----> 3 commits = [commit for commit in commit['committer']]
#       4 commits
#
# TypeError: list indices must be integers or slices, not str
