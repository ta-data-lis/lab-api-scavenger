# %%
import requests
import json
import pandas as pd
from requests.auth import HTTPBasicAuth
from getpass import getpass
import numpy as np

# %% [markdown]
# ### Challenge 1

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'


resp = requests.get(url) 
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '[{"id":235625657,"node_id":"MDEwOlJlcG9zaXRvcnkyMzU2MjU2NTc=","name":"python-project","full_name":"4kiUta/python-project","private":false,"owner":{"login":"4kiUta","id":58987872,"node_id":"MDQ6VXNlcjU4OTg3ODcy","avatar_url":"https://avatars1.githubusercontent.com/u/58987872?v=4","gravatar_id":"","url":"https://api.github.com/users/4kiUta","html_url":"https://github.com/4kiUta","followers_url":"https://api.github.com/users/4kiUta/followers","following_url":"https://api.github.com/users/4kiUta/following{/other_user}","gists_url":"https://api.github.com/users/4kiUta/gists{/gist_id}","starred_url":"https://api.github.com/users/4kiUta/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/4kiUta/subscriptions","organizations_url":"https://api.github.com/users/4kiUta/orgs","repos_url":"https://api.github.com/users/4kiUta/repos","events_url":"https://api.github.com/users/4kiUta/events{/privacy}","received_events_url":"https://api.github.com/users/4kiUta/received_events",
# ...

# %%
ds = pd.DataFrame(resp.json())

# %%
list(ds.columns)
# Out:
# ['id',
#  'node_id',
#  'name',
#  'full_name',
#  'private',
#  'owner',
#  'html_url',
#  'description',
#  'fork',
#  'url',
#  'forks_url',
#  'keys_url',
#  'collaborators_url',
#  'teams_url',
#  'hooks_url',
#  'issue_events_url',
#  'events_url',
#  'assignees_url',
#  'branches_url',
#  'tags_url',
#  'blobs_url',
#  'git_tags_url',
#  'git_refs_url',
#  'trees_url',
#  'statuses_url',
#  'languages_url',
#  'stargazers_url',
#  'contributors_url',
#  'subscribers_url',
#  'subscription_url',
#  'commits_url',
#  'git_commits_url',
#  'comments_url',
#  'issue_comment_url',
#  'contents_url',
#  'compare_url',
#  'merges_url',
#  'archive_url',
#  'downloads_url',
#  'issues_url',
#  'pulls_url',
#  'milestones_url',
#  'notifications_url',
#  'labels_url',
#  'releases_url',
#  'deployments_url',
#  'created_at',
#  'updated_at',
#  'pushed_at',
#  'git_url',
#  'ssh_url',
#  'clone_url',
#  'svn_url',
#  'homepage',
#  'size',
#  'stargazers_count',
#  'watchers_count',
# ...

# %%
ds['language'].dropna
# Out:
# <bound method Series.dropna of 0                 None
# 1                 None
# 2     Jupyter Notebook
# 3     Jupyter Notebook
# 4     Jupyter Notebook
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10    Jupyter Notebook
# 11    Jupyter Notebook
# Name: language, dtype: object>

# %%
set(np.array(ds['language']))
# Out:
# {'Jupyter Notebook', None}

# %% [markdown]
# ### Challenge 2

# %%
url = 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'


resp = requests.get(url) 
resp.status_code
# Out:
# 200

# %%
ds = pd.DataFrame(resp.json())

# %%
ds.shape
# Out:
# (4, 9)

# %%
list(ds.columns)
# Out:
# ['sha',
#  'node_id',
#  'commit',
#  'url',
#  'html_url',
#  'comments_url',
#  'author',
#  'committer',
#  'parents']

# %%
from pandas.io.json import json_normalize
norm_json = json_normalize(resp.json())

# %%
list(norm_json.columns)
# Out:
# ['sha',
#  'node_id',
#  'url',
#  'html_url',
#  'comments_url',
#  'parents',
#  'commit.author.name',
#  'commit.author.email',
#  'commit.author.date',
#  'commit.committer.name',
#  'commit.committer.email',
#  'commit.committer.date',
#  'commit.message',
#  'commit.tree.sha',
#  'commit.tree.url',
#  'commit.url',
#  'commit.comment_count',
#  'commit.verification.verified',
#  'commit.verification.reason',
#  'commit.verification.signature',
#  'commit.verification.payload',
#  'author.login',
#  'author.id',
#  'author.node_id',
#  'author.avatar_url',
#  'author.gravatar_id',
#  'author.url',
#  'author.html_url',
#  'author.followers_url',
#  'author.following_url',
#  'author.gists_url',
#  'author.starred_url',
#  'author.subscriptions_url',
#  'author.organizations_url',
#  'author.repos_url',
#  'author.events_url',
#  'author.received_events_url',
#  'author.type',
#  'author.site_admin',
#  'committer.login',
#  'committer.id',
#  'committer.node_id',
# ...

# %%
type(norm_json['commit.author.date'][0])
# Out:
# str

# %%
norm_json['commit.author.date'] = pd.to_datetime(norm_json['commit.author.date'])
comm=norm_json[norm_json['commit.author.date']> '2020-01-20']

# %%
norm_json['commit.author.date']
# Out:
# 0   2019-08-19 11:12:15+00:00
# 1   2019-08-19 11:11:55+00:00
# 2   2019-08-19 11:10:23+00:00
# 3   2019-08-19 08:36:54+00:00
# Name: commit.author.date, dtype: datetime64[ns, UTC]

# %%
comm.shape[0]  ##
# Out:
# 0
