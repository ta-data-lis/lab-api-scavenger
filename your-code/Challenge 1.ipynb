# %%
'''
### Challenge 1: Fork Languages

You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is `ironhack-datalabs/datalis0819`, you will:

1. Obtain the full list of forks created from the main lab repo via Github API.

1. Loop the JSON response to find out the `language` attribute of each fork. Use an array to store the `language` attributes of each fork.
    * *Hint: Each language should appear only once in your array.*

1. Print the language array. It should be something like:

	```["Python", "Jupyter Notebook", "HTML"]```

Again, the documentation of Github API is [here](https://developer.github.com/v3/).

'''
# Out:
# '\n### Challenge 1: Fork Languages\n\nYou will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is `ironhack-datalabs/datalis0819`, you will:\n\n1. Obtain the full list of forks created from the main lab repo via Github API.\n\n1. Loop the JSON response to find out the `language` attribute of each fork. Use an array to store the `language` attributes of each fork.\n    * *Hint: Each language should appear only once in your array.*\n\n1. Print the language array. It should be something like:\n\n\t```["Python", "Jupyter Notebook", "HTML"]```\n\nAgain, the documentation of Github API is [here](https://developer.github.com/v3/).\n\n'

# %%
#import libraries
import requests
import json
import pandas as pd

# %%
#import API info

url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

response = requests.get(url)#.json()

#GET /repos/:owner/:repo/forks

response
# Out:
# <Response [200]>

# %%
#create dataframe full list of forks
df = pd.DataFrame(response.json())
df.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/Inrx/datalis0819/...     False
# 1  https://api.github.com/repos/laurawuerz/datali...     False
# 2  https://api.github.com/repos/filipamiralopes/d...     False
# 3  https://api.github.com/repos/janpotthoff/datal...     False
# 4  https://api.github.com/repos/sofia-sousa/datal...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/Inrx/datalis0819/...
# 1  https://api.github.com/repos/laurawuerz/datali...
# 2  https://api.github.com/repos/filipamiralopes/d...
# 3  https://api.github.com/repos/janpotthoff/datal...
# 4  https://api.github.com/repos/sofia-sousa/datal...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/Inrx/datalis0819/...
# 1  https://api.github.com/repos/laurawuerz/datali...
# 2  https://api.github.com/repos/filipamiralopes/d...
# ...

# %%
df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner', 'private', 'pulls_url',
#        'pushed_at', 'releases_url', 'size', 'ssh_url', 'stargazers_count',
# ...

# %%
df.shape
# Out:
# (11, 73)

# %%
type(response)
# Out:
# requests.models.Response

# %%
df_fork_language = df[['name', 'fork', 'forks_count','language']]
df_fork_language.head()
# Out:
#           name  fork  forks_count          language
# 0  datalis0819  True            0  Jupyter Notebook
# 1  datalis0819  True            0  Jupyter Notebook
# 2  datalis0819  True            0  Jupyter Notebook
# 3  datalis0819  True            0  Jupyter Notebook
# 4  datalis0819  True            0  Jupyter Notebook

# %%
language = df['language'].unique().tolist()
print(language)
# Out:
# ['Jupyter Notebook']
