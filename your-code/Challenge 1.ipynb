# %%
"""Challenge 1: Fork Languages
You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datalis0819, you will:

Obtain the full list of forks created from the main lab repo via Github API.

Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.

Hint: Each language should appear only once in your array.
Print the language array. It should be something like:

["Python", "Jupyter Notebook", "HTML"]

Again, the documentation of Github API is here."""

# %%
import requests
import json
import pandas as pd

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819'
resp = requests.get(url, auth = HTTPBasicAuth('Mariana427', "44f052c1bd9fa8e6c80358975b3178f040b349cf"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f30e8d6ac7f5> in <module>
#       1 url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819'
# ----> 2 resp = requests.get(url, auth = HTTPBasicAuth('Mariana427', "44f052c1bd9fa8e6c80358975b3178f040b349cf"))
#
# NameError: name 'HTTPBasicAuth' is not defined

# %%
results = resp.json()
results
# Out:
# [{'login': 'carlosmd14',
#   'id': 45972288,
#   'node_id': 'MDQ6VXNlcjQ1OTcyMjg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/45972288?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/carlosmd14',
#   'html_url': 'https://github.com/carlosmd14',
#   'followers_url': 'https://api.github.com/users/carlosmd14/followers',
#   'following_url': 'https://api.github.com/users/carlosmd14/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/carlosmd14/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/carlosmd14/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/carlosmd14/subscriptions',
#   'organizations_url': 'https://api.github.com/users/carlosmd14/orgs',
#   'repos_url': 'https://api.github.com/users/carlosmd14/repos',
#   'events_url': 'https://api.github.com/users/carlosmd14/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/carlosmd14/received_events',
#   'type': 'User',
#   'site_admin': False,
#   'contributions': 27},
#  {'login': 'carlarsmendes',
#   'id': 38359702,
#   'node_id': 'MDQ6VXNlcjM4MzU5NzAy',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/38359702?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/carlarsmendes',
#   'html_url': 'https://github.com/carlarsmendes',
#   'followers_url': 'https://api.github.com/users/carlarsmendes/followers',
#   'following_url': 'https://api.github.com/users/carlarsmendes/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/carlarsmendes/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/carlarsmendes/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/carlarsmendes/subscriptions',
#   'organizations_url': 'https://api.github.com/users/carlarsmendes/orgs',
#   'repos_url': 'https://api.github.com/users/carlarsmendes/repos',
#   'events_url': 'https://api.github.com/users/carlarsmendes/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/carlarsmendes/received_events',
#   'type': 'User',
#   'site_admin': False,
#   'contributions': 16},
#  {'login': 'kelsey-ironhack',
#   'id': 52278191,
#   'node_id': 'MDQ6VXNlcjUyMjc4MTkx',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/52278191?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kelsey-ironhack',
#   'html_url': 'https://github.com/kelsey-ironhack',
#   'followers_url': 'https://api.github.com/users/kelsey-ironhack/followers',
#   'following_url': 'https://api.github.com/users/kelsey-ironhack/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kelsey-ironhack/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/kelsey-ironhack/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kelsey-ironhack/subscriptions',
#   'organizations_url': 'https://api.github.com/users/kelsey-ironhack/orgs',
#   'repos_url': 'https://api.github.com/users/kelsey-ironhack/repos',
#   'events_url': 'https://api.github.com/users/kelsey-ironhack/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/kelsey-ironhack/received_events',
#   'type': 'User',
#   'site_admin': False,
#   'contributions': 13}]

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                           avatar_url  contributions  \
# 0  https://avatars2.githubusercontent.com/u/45972...             27
# 1  https://avatars0.githubusercontent.com/u/38359...             16
# 2  https://avatars0.githubusercontent.com/u/52278...             13
#
#                                           events_url  \
# 0  https://api.github.com/users/carlosmd14/events...
# 1  https://api.github.com/users/carlarsmendes/eve...
# 2  https://api.github.com/users/kelsey-ironhack/e...
#
#                                        followers_url  \
# 0  https://api.github.com/users/carlosmd14/followers
# 1  https://api.github.com/users/carlarsmendes/fol...
# 2  https://api.github.com/users/kelsey-ironhack/f...
#
#                                        following_url  \
# 0  https://api.github.com/users/carlosmd14/follow...
# 1  https://api.github.com/users/carlarsmendes/fol...
# 2  https://api.github.com/users/kelsey-ironhack/f...
#
#                                            gists_url gravatar_id  \
# 0  https://api.github.com/users/carlosmd14/gists{...
# 1  https://api.github.com/users/carlarsmendes/gis...
# 2  https://api.github.com/users/kelsey-ironhack/g...
#
#                              html_url        id            login  \
# 0       https://github.com/carlosmd14  45972288       carlosmd14
# 1    https://github.com/carlarsmendes  38359702    carlarsmendes
# 2  https://github.com/kelsey-ironhack  52278191  kelsey-ironhack
#
#                 node_id                                  organizations_url  \
# 0  MDQ6VXNlcjQ1OTcyMjg4       https://api.github.com/users/carlosmd14/orgs
# 1  MDQ6VXNlcjM4MzU5NzAy    https://api.github.com/users/carlarsmendes/orgs
# 2  MDQ6VXNlcjUyMjc4MTkx  https://api.github.com/users/kelsey-ironhack/orgs
#
#                                  received_events_url  \
# 0  https://api.github.com/users/carlosmd14/receiv...
# 1  https://api.github.com/users/carlarsmendes/rec...
# 2  https://api.github.com/users/kelsey-ironhack/r...
#
#                                            repos_url  site_admin  \
# 0      https://api.github.com/users/carlosmd14/repos       False
# 1   https://api.github.com/users/carlarsmendes/repos       False
# 2  https://api.github.com/users/kelsey-ironhack/r...       False
#
#                                          starred_url  \
# 0  https://api.github.com/users/carlosmd14/starre...
# 1  https://api.github.com/users/carlarsmendes/sta...
# 2  https://api.github.com/users/kelsey-ironhack/s...
#
#                                    subscriptions_url  type  \
# 0  https://api.github.com/users/carlosmd14/subscr...  User
# 1  https://api.github.com/users/carlarsmendes/sub...  User
# 2  https://api.github.com/users/kelsey-ironhack/s...  User
#
#                                             url
# 0       https://api.github.com/users/carlosmd14
# 1    https://api.github.com/users/carlarsmendes
# 2  https://api.github.com/users/kelsey-ironhack

# %%
lst = [i for i in data["language"]] 

test_list = list(set(lst)) 
test_list
# Out:
# ['carlosmd14', 'kelsey-ironhack', 'carlarsmendes']
