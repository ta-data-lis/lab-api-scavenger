# %%
import requests
import json
import pandas as pd

# %%
url= "https://api.github.com/repos/ironhack-datalabs/datalis0819/forks"
resp = requests.get(url)

resp
# Out:
# <Response [200]>

# %%
#CHALLENGE 1


resp = requests.get('https://api.github.com/repos/ironhack-datalabs/datalis0819/forks')
ds_scavenger = pd.DataFrame(resp.json())
ds_scavenger.head(10)
# Out:
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7  201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8  201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
#
#                      full_name  private  \
# 0       Mariana427/datalis0819    False
# 1   EvelienDonkers/datalis0819    False
# 2      ta-data-lis/datalis0819    False
# 3             Inrx/datalis0819    False
# 4  filipamiralopes/datalis0819    False
# 5      janpotthoff/datalis0819    False
# ...

# %%
#Obtain the full list of forks created from the main lab repo via Github API.
#Loop the JSON response to find out the `language` attribute of each fork. 
#Use an array to store the `language` attributes of each fork.
#Hint: Each language should appear only once in your array.*

#Print the language array. It should be something like:
#```["Python", "Jupyter Notebook", "HTML"]```

#Again, the documentation of Github API is [here](https://developer.github.com/v3/).

# %%
from pandas.io.json import json_normalize

norm_json = json_normalize(resp.json())
ds_normalized_scavenger = pd.DataFrame(norm_json)
ds_normalized_scavenger.head(10)
# Out:
# C:\Users\Gabriela Scatena\Anaconda3\envs\IronHack1\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7  201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8  201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
#
# ...

# %%
ds_normalized_scavenger.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
cond_scavenger=ds_normalized_scavenger["forks"]==ds_normalized_scavenger["forks"].sum()
ds_normalized_scavenger[cond_scavenger]
# Out:
#            id                           node_id         name  \
# 0   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 10  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 11  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0        Mariana427/datalis0819    False
# 1    EvelienDonkers/datalis0819    False
# 2       ta-data-lis/datalis0819    False
# ...

# %%
ds_normalized_scavenger["language"].unique() #return array([None, 'Jupyter Notebook'], dtype=object)
# Out:
# array([None, 'Jupyter Notebook'], dtype=object)
