# %%
import pandas as pd
import requests
import json

# %%
# Challenge 1

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'
response = requests.get(url).json()
ds = pd.DataFrame(response)

# %%
ds
# Out:
#            id                           node_id         name  \
# 0   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 1   202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 2   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 3   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 4   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 5   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 6   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 7   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 8   199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 9   198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
# 10  198658615  MDEwOlJlcG9zaXRvcnkxOTg2NTg2MTU=  datalis0819
#
#                       full_name  private  \
# 0              Inrx/datalis0819    False
# 1        laurawuerz/datalis0819    False
# 2   filipamiralopes/datalis0819    False
# 3       janpotthoff/datalis0819    False
# ...

# %%
languages=list(ds['language'])
print(languages)
# Out:
# ['Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
# Challenge 2

# %%
url1 = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/commits?since=2019-08-01T00:00:00'
response1 = requests.get(url1).json()
ds1 = pd.DataFrame(response1)
ds1
# Out:
#                                          sha  \
# 0   abebdae9e9f22a43419ae23520e93fafbce5a238
# 1   9f8892572f69b657afc2c1d8fc86feaa26a854fc
# 2   dad154e138221514f3a307a02992afe6a4da7d22
# 3   d4111da8c59075a6250742b26f8ffcf11062a594
# 4   ec14215572a45a8c241c8b9fb3622c66810872f6
# 5   f343d176f35b4b545c858c1a9d5db8bab788a7eb
# 6   a83168ce17558c88e7599d382125672d66315167
# 7   f0729d44ad197232873bf77c3bee76ce5a207661
# 8   f67d9f87ee9de4902f62cd8739e52db9d5d41614
# 9   7551ef430c03048f790eb895830f04fd80f57d43
# 10  d1260e3735127901c448ba7375f9b93cdf413ebd
# 11  4923d216897856fd2120cd33af7253c42b83784a
# 12  83dbc5b2edaddb47343279ac4573acb51957c9cd
# 13  de987d732d0921df1331675e1d6f9f8822c03972
# 14  ebaae31787068ae45f8fb48dcf9e95e2917c0881
# 15  25870fd44f798a1e226e054954b7bc97b709e97c
# 16  c99f7890cb0aece7cb8130e3d558da549e624162
# 17  a3f0ac2570680f9cbd7f5e61eb3a529f9ab49de7
# 18  5d90a06f40717a6cd53d2d1f1260d747bafda0d4
# 19  699399be34b7ac266299265909f03e78f8e25e2a
# ...

# %%
commits = len(list(ds1['commit']))
commits
# Out:
# 30

# %%
# Challenge 3

# %%
url2 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
response2 = requests.get(url2).json()
ds2 = pd.DataFrame(response2)

# %%
ds2
# Out:
#           name        path                                       sha  size  \
# 0   .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1        15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2        15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3        17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4        30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5        40303       40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6        44639       44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7        45525       45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8        47222       47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9        47830       47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10       49418       49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# ...
