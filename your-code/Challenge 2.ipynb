# %% [markdown]
# CHALLENGE 2 :
#
# how many commits were made in the past 2 weeks:
#
# Obtain all the commits made in the past 2 weeks via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
# first steps:

url = 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'

resp = requests.get(url) 
resp.status_code
# Out:
# 200

# %%
ds_scavenger2 = pd.DataFrame(resp.json())
ds_scavenger2.head(10)
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carla Mendes', 'email': '...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
#Obtain all the commits made in the past 2 weeks


norm_json2 = json_normalize(resp.json())
ds_normalized_scavenger2 = pd.DataFrame(norm_json2)
ds_normalized_scavenger2.head(10)

#ds_normalized_scavenger2.columns
# Out:
# C:\Users\Gabriela Scatena\Anaconda3\envs\IronHack1\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# 2  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
#ds_normalized_scavenger2["commit.author.date"]
#as i want the data from the person who made the commit, i will need to use de old data, befora normalized or it wont give me the commit {}
# Out:
# 0    2019-08-19T11:12:15Z
# 1    2019-08-19T11:11:55Z
# 2    2019-08-19T11:10:23Z
# 3    2019-08-19T08:36:54Z
# Name: commit.author.date, dtype: object

# %%
ds_scavenger2.columns
# Out:
# Index(['sha', 'node_id', 'commit', 'url', 'html_url', 'comments_url', 'author',
#        'committer', 'parents'],
#       dtype='object')

# %%
ds_scavenger2['commit']
# Out:
# 0    {'author': {'name': 'Carlos Madriz', 'email': ...
# 1    {'author': {'name': 'Carlos Madriz', 'email': ...
# 2    {'author': {'name': 'Carlos Madriz', 'email': ...
# 3    {'author': {'name': 'Carla Mendes', 'email': '...
# Name: commit, dtype: object

# %%
#and now that i have the data from the commit, i normalized the column:

scavenger2_commit = json_normalize(ds_scavenger2['commit'])
scavenger2_commit.head()
# Out:
# C:\Users\Gabriela Scatena\Anaconda3\envs\IronHack1\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 message                                                url  \
# 0      Update README.md  https://api.github.com/repos/ta-data-lis/lab-m...
# 1      Update README.md  https://api.github.com/repos/ta-data-lis/lab-m...
# 2  Added AppleStore.csv  https://api.github.com/repos/ta-data-lis/lab-m...
# 3          first commit  https://api.github.com/repos/ta-data-lis/lab-m...
#
#    comment_count    author.name                                  author.email  \
# 0              0  Carlos Madriz  45972288+carlosmd14@users.noreply.github.com
# 1              0  Carlos Madriz  45972288+carlosmd14@users.noreply.github.com
# 2              0  Carlos Madriz  45972288+carlosmd14@users.noreply.github.com
# ...

# %%
scavenger2_commit['commit.author.date'] = pd.to_datetime(norm_json2['commit.author.date'])
norm_json2[norm_json2['commit.author.date']> '2020-01-23']


#need help, i dont understand this output... 
#This means that all the commits happens before this date? and we have none or i did something wrong?
# Out:
# Empty DataFrame
# ...

# %%
# Out:
# 0    2019-08-19T11:12:15Z
# 1    2019-08-19T11:11:55Z
# 2    2019-08-19T11:10:23Z
# 3    2019-08-19T08:36:54Z
# Name: commit.author.date, dtype: object
