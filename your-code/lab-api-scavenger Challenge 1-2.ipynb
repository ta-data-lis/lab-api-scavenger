# %%
import requests
import json 
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datalis0819/forks"


# get method from requests
response = requests.get(url).json()

# check if you have the info
response
ds = pd.DataFrame(response)
ds.head()
# Out:
#           id                           node_id         name  \
# 0  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 1  202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 2  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 3  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 4  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
#
#                      full_name  private  \
# 0             Inrx/datalis0819    False
# 1       laurawuerz/datalis0819    False
# 2  filipamiralopes/datalis0819    False
# 3      janpotthoff/datalis0819    False
# 4      sofia-sousa/datalis0819    False
#
#                                                owner  \
# 0  {'login': 'Inrx', 'id': 49349821, 'node_id': '...
# 1  {'login': 'laurawuerz', 'id': 52656811, 'node_...
# 2  {'login': 'filipamiralopes', 'id': 42877871, '...
# 3  {'login': 'janpotthoff', 'id': 53485922, 'node...
# 4  {'login': 'sofia-sousa', 'id': 53151504, 'node...
#
#                                          html_url  \
# 0             https://github.com/Inrx/datalis0819
# 1       https://github.com/laurawuerz/datalis0819
# 2  https://github.com/filipamiralopes/datalis0819
# 3      https://github.com/janpotthoff/datalis0819
# 4      https://github.com/sofia-sousa/datalis0819
#
#                                     description  fork  \
# 0  Data Analytics Full Time Lisbon, August 2019  True
# 1  Data Analytics Full Time Lisbon, August 2019  True
# 2  Data Analytics Full Time Lisbon, August 2019  True
# 3  Data Analytics Full Time Lisbon, August 2019  True
# 4  Data Analytics Full Time Lisbon, August 2019  True
#
#                                                  url  ... forks_count  \
# 0      https://api.github.com/repos/Inrx/datalis0819  ...           0
# 1  https://api.github.com/repos/laurawuerz/datali...  ...           0
# 2  https://api.github.com/repos/filipamiralopes/d...  ...           0
# 3  https://api.github.com/repos/janpotthoff/datal...  ...           0
# 4  https://api.github.com/repos/sofia-sousa/datal...  ...           0
#
#   mirror_url archived disabled open_issues_count  \
# 0       None    False    False                 0
# 1       None    False    False                 0
# 2       None    False    False                 0
# 3       None    False    False                 0
# 4       None    False    False                 0
#
#                                              license forks open_issues  \
# 0  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 1  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 2  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 3  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 4  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
#
#   watchers default_branch
# 0        0         master
# 1        0         master
# 2        0         master
# 3        0         master
# 4        0         master
#
# [5 rows x 73 columns]

# %%
# Cristina Version
forks = json_normalize(response);
forks.head()
# Out:
#           id                           node_id         name  \
# 0  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 1  202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 2  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 3  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 4  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
#
#                      full_name  private  \
# 0             Inrx/datalis0819    False
# 1       laurawuerz/datalis0819    False
# 2  filipamiralopes/datalis0819    False
# 3      janpotthoff/datalis0819    False
# 4      sofia-sousa/datalis0819    False
#
#                                          html_url  \
# 0             https://github.com/Inrx/datalis0819
# 1       https://github.com/laurawuerz/datalis0819
# 2  https://github.com/filipamiralopes/datalis0819
# 3      https://github.com/janpotthoff/datalis0819
# 4      https://github.com/sofia-sousa/datalis0819
#
#                                     description  fork  \
# 0  Data Analytics Full Time Lisbon, August 2019  True
# 1  Data Analytics Full Time Lisbon, August 2019  True
# 2  Data Analytics Full Time Lisbon, August 2019  True
# 3  Data Analytics Full Time Lisbon, August 2019  True
# 4  Data Analytics Full Time Lisbon, August 2019  True
#
#                                                  url  \
# 0      https://api.github.com/repos/Inrx/datalis0819
# 1  https://api.github.com/repos/laurawuerz/datali...
# 2  https://api.github.com/repos/filipamiralopes/d...
# 3  https://api.github.com/repos/janpotthoff/datal...
# 4  https://api.github.com/repos/sofia-sousa/datal...
#
#                                            forks_url  ...  \
# 0  https://api.github.com/repos/Inrx/datalis0819/...  ...
# 1  https://api.github.com/repos/laurawuerz/datali...  ...
# 2  https://api.github.com/repos/filipamiralopes/d...  ...
# 3  https://api.github.com/repos/janpotthoff/datal...  ...
# 4  https://api.github.com/repos/sofia-sousa/datal...  ...
#
#                                      owner.repos_url  \
# 0            https://api.github.com/users/Inrx/repos
# 1      https://api.github.com/users/laurawuerz/repos
# 2  https://api.github.com/users/filipamiralopes/r...
# 3     https://api.github.com/users/janpotthoff/repos
# 4     https://api.github.com/users/sofia-sousa/repos
#
#                                     owner.events_url  \
# 0  https://api.github.com/users/Inrx/events{/priv...
# 1  https://api.github.com/users/laurawuerz/events...
# 2  https://api.github.com/users/filipamiralopes/e...
# 3  https://api.github.com/users/janpotthoff/event...
# 4  https://api.github.com/users/sofia-sousa/event...
#
#                            owner.received_events_url owner.type  \
# 0  https://api.github.com/users/Inrx/received_events       User
# 1  https://api.github.com/users/laurawuerz/receiv...       User
# 2  https://api.github.com/users/filipamiralopes/r...       User
# 3  https://api.github.com/users/janpotthoff/recei...       User
# 4  https://api.github.com/users/sofia-sousa/recei...       User
#
#   owner.site_admin license.key                            license.name  \
# 0            False    agpl-3.0  GNU Affero General Public License v3.0
# 1            False    agpl-3.0  GNU Affero General Public License v3.0
# 2            False    agpl-3.0  GNU Affero General Public License v3.0
# 3            False    agpl-3.0  GNU Affero General Public License v3.0
# 4            False    agpl-3.0  GNU Affero General Public License v3.0
#
#   license.spdx_id                               license.url   license.node_id
# 0        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 1        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 2        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 3        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 4        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
#
# [5 rows x 94 columns]

# %%
ds["owner"][0]

#from pandas.io.json import json_normalize

#norm_json = json_normalize(response.json())
#ds_normalized = pd.DataFrame(ds)
#ds_normalized.head()
from pandas.io.json import json_normalize

norm_json = json_normalize(response)
ds_normalized = pd.DataFrame(norm_json)
ds_normalized.head(10)
# Out:
#           id                           node_id         name  \
# 0  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 1  202144164  MDEwOlJlcG9zaXRvcnkyMDIxNDQxNjQ=  datalis0819
# 2  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 3  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 4  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 5  201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 6  201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 7  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 8  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 9  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                      full_name  private  \
# 0             Inrx/datalis0819    False
# 1       laurawuerz/datalis0819    False
# 2  filipamiralopes/datalis0819    False
# 3      janpotthoff/datalis0819    False
# 4      sofia-sousa/datalis0819    False
# 5            naivm/datalis0819    False
# 6         LindaRit/datalis0819    False
# 7        Ana-Andre/datalis0819    False
# 8       alonasorochynska/data2    False
# 9    carlarsmendes/datalis0819    False
#
#                                          html_url  \
# 0             https://github.com/Inrx/datalis0819
# 1       https://github.com/laurawuerz/datalis0819
# 2  https://github.com/filipamiralopes/datalis0819
# 3      https://github.com/janpotthoff/datalis0819
# 4      https://github.com/sofia-sousa/datalis0819
# 5            https://github.com/naivm/datalis0819
# 6         https://github.com/LindaRit/datalis0819
# 7        https://github.com/Ana-Andre/datalis0819
# 8       https://github.com/alonasorochynska/data2
# 9    https://github.com/carlarsmendes/datalis0819
#
#                                     description  fork  \
# 0  Data Analytics Full Time Lisbon, August 2019  True
# 1  Data Analytics Full Time Lisbon, August 2019  True
# 2  Data Analytics Full Time Lisbon, August 2019  True
# 3  Data Analytics Full Time Lisbon, August 2019  True
# 4  Data Analytics Full Time Lisbon, August 2019  True
# 5  Data Analytics Full Time Lisbon, August 2019  True
# 6  Data Analytics Full Time Lisbon, August 2019  True
# 7  Data Analytics Full Time Lisbon, August 2019  True
# 8  Data Analytics Full Time Lisbon, August 2019  True
# 9  Data Analytics Full Time Lisbon, August 2019  True
#
#                                                  url  \
# 0      https://api.github.com/repos/Inrx/datalis0819
# 1  https://api.github.com/repos/laurawuerz/datali...
# 2  https://api.github.com/repos/filipamiralopes/d...
# 3  https://api.github.com/repos/janpotthoff/datal...
# 4  https://api.github.com/repos/sofia-sousa/datal...
# 5     https://api.github.com/repos/naivm/datalis0819
# 6  https://api.github.com/repos/LindaRit/datalis0819
# 7  https://api.github.com/repos/Ana-Andre/datalis...
# 8  https://api.github.com/repos/alonasorochynska/...
# 9  https://api.github.com/repos/carlarsmendes/dat...
#
#                                            forks_url  ...  \
# 0  https://api.github.com/repos/Inrx/datalis0819/...  ...
# 1  https://api.github.com/repos/laurawuerz/datali...  ...
# 2  https://api.github.com/repos/filipamiralopes/d...  ...
# 3  https://api.github.com/repos/janpotthoff/datal...  ...
# 4  https://api.github.com/repos/sofia-sousa/datal...  ...
# 5  https://api.github.com/repos/naivm/datalis0819...  ...
# 6  https://api.github.com/repos/LindaRit/datalis0...  ...
# 7  https://api.github.com/repos/Ana-Andre/datalis...  ...
# 8  https://api.github.com/repos/alonasorochynska/...  ...
# 9  https://api.github.com/repos/carlarsmendes/dat...  ...
#
#                                      owner.repos_url  \
# 0            https://api.github.com/users/Inrx/repos
# 1      https://api.github.com/users/laurawuerz/repos
# 2  https://api.github.com/users/filipamiralopes/r...
# 3     https://api.github.com/users/janpotthoff/repos
# 4     https://api.github.com/users/sofia-sousa/repos
# 5           https://api.github.com/users/naivm/repos
# 6        https://api.github.com/users/LindaRit/repos
# 7       https://api.github.com/users/Ana-Andre/repos
# 8  https://api.github.com/users/alonasorochynska/...
# 9   https://api.github.com/users/carlarsmendes/repos
#
#                                     owner.events_url  \
# 0  https://api.github.com/users/Inrx/events{/priv...
# 1  https://api.github.com/users/laurawuerz/events...
# 2  https://api.github.com/users/filipamiralopes/e...
# 3  https://api.github.com/users/janpotthoff/event...
# 4  https://api.github.com/users/sofia-sousa/event...
# 5  https://api.github.com/users/naivm/events{/pri...
# 6  https://api.github.com/users/LindaRit/events{/...
# 7  https://api.github.com/users/Ana-Andre/events{...
# 8  https://api.github.com/users/alonasorochynska/...
# 9  https://api.github.com/users/carlarsmendes/eve...
#
#                            owner.received_events_url owner.type  \
# 0  https://api.github.com/users/Inrx/received_events       User
# 1  https://api.github.com/users/laurawuerz/receiv...       User
# 2  https://api.github.com/users/filipamiralopes/r...       User
# 3  https://api.github.com/users/janpotthoff/recei...       User
# 4  https://api.github.com/users/sofia-sousa/recei...       User
# 5  https://api.github.com/users/naivm/received_ev...       User
# 6  https://api.github.com/users/LindaRit/received...       User
# 7  https://api.github.com/users/Ana-Andre/receive...       User
# 8  https://api.github.com/users/alonasorochynska/...       User
# 9  https://api.github.com/users/carlarsmendes/rec...       User
#
#   owner.site_admin license.key                            license.name  \
# 0            False    agpl-3.0  GNU Affero General Public License v3.0
# 1            False    agpl-3.0  GNU Affero General Public License v3.0
# 2            False    agpl-3.0  GNU Affero General Public License v3.0
# 3            False    agpl-3.0  GNU Affero General Public License v3.0
# 4            False    agpl-3.0  GNU Affero General Public License v3.0
# 5            False    agpl-3.0  GNU Affero General Public License v3.0
# 6            False    agpl-3.0  GNU Affero General Public License v3.0
# 7            False    agpl-3.0  GNU Affero General Public License v3.0
# 8            False    agpl-3.0  GNU Affero General Public License v3.0
# 9            False    agpl-3.0  GNU Affero General Public License v3.0
#
#   license.spdx_id                               license.url   license.node_id
# 0        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 1        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 2        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 3        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 4        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 5        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 6        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 7        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 8        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 9        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
#
# [10 rows x 94 columns]

# %%
ds["language"]

language = set(ds["language"])
language
# Out:
# {'Jupyter Notebook'}

# %%
# Cristinas version

languages=[]
languages = [language for language in forks["language"] if language not in languages]
set(languages)
# Out:
# {'Jupyter Notebook'}

# %%
ds.shape
# Out:
# (11, 73)

# %%
ds.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license',
#        'forks', 'open_issues', 'watchers', 'default_branch'],
#       dtype='object')

# %% [markdown]
# # Challenge 2

# %%
# how many commits past week = 19.08.2019
len(ds["git_commits_url"])

urlcommits = "https://api.github.com/repos/ironhack-datalabs/datalis0819/commits?since=2019-08-19T00:00:00"
# get method from requests
response_commit = requests.get(urlcommits).json()

# check if you have the info

ds_commit = pd.DataFrame(response_commit)
ds_commit
#len(ds_commit)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ds[['git_commits_url', 'created_at']]
# Out:
#                                       git_commits_url            created_at
# 0   https://api.github.com/repos/Inrx/datalis0819/...  2019-08-26T16:10:26Z
# 1   https://api.github.com/repos/laurawuerz/datali...  2019-08-13T12:53:18Z
# 2   https://api.github.com/repos/filipamiralopes/d...  2019-08-12T17:06:11Z
# 3   https://api.github.com/repos/janpotthoff/datal...  2019-08-12T15:49:50Z
# 4   https://api.github.com/repos/sofia-sousa/datal...  2019-08-12T15:20:26Z
# 5   https://api.github.com/repos/naivm/datalis0819...  2019-08-12T15:20:19Z
# 6   https://api.github.com/repos/LindaRit/datalis0...  2019-08-12T15:20:00Z
# 7   https://api.github.com/repos/Ana-Andre/datalis...  2019-08-12T15:19:40Z
# 8   https://api.github.com/repos/alonasorochynska/...  2019-07-29T15:49:59Z
# 9   https://api.github.com/repos/carlarsmendes/dat...  2019-07-24T20:30:00Z
# 10  https://api.github.com/repos/carlosmd14/datali...  2019-07-24T15:05:51Z

# %%
ds["forks_url"]
# Out:
# 0     https://api.github.com/repos/Inrx/datalis0819/...
# 1     https://api.github.com/repos/laurawuerz/datali...
# 2     https://api.github.com/repos/filipamiralopes/d...
# 3     https://api.github.com/repos/janpotthoff/datal...
# 4     https://api.github.com/repos/sofia-sousa/datal...
# 5     https://api.github.com/repos/naivm/datalis0819...
# 6     https://api.github.com/repos/LindaRit/datalis0...
# 7     https://api.github.com/repos/Ana-Andre/datalis...
# 8     https://api.github.com/repos/alonasorochynska/...
# 9     https://api.github.com/repos/carlarsmendes/dat...
# 10    https://api.github.com/repos/carlosmd14/datali...
# Name: forks_url, dtype: object
