# %%
#1

import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import json

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'

r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data = r.json()
data

# %%
'language' in data[0].keys()
# Out:
# True

# %%
list({repo['language'] for repo in data}) # create a list -> access repo dictionary and look for language key, access it where there is a dictionary and retrieve the languages
# Out:
# ['Jupyter Notebook', 'HTML', None]

# %%
#2

url = 'https://api.github.com/repos/cornelioz/lab-python-list-dict-set-comprehension/commits'

params = {'since': '2023-07-14T17:36:05Z'}
r = requests.get(url, params=params)
r
# Out:
# <Response [200]>

# %%
data = r.json()
data
# Out:
# [{'sha': '65a9fd646f479806ab7cd68073785eb87be702e6',
#   'node_id': 'C_kwDOJ8j-o9oAKDY1YTlmZDY0NmY0Nzk4MDZhYjdjZDY4MDczNzg1ZWI4N2JlNzAyZTY',
#   'commit': {'author': {'name': 'Nuno Silva',
#     'email': 'nunocornelio@gmail.com',
#     'date': '2023-07-18T15:05:36Z'},
#    'committer': {'name': 'Nuno Silva',
#     'email': 'nunocornelio@gmail.com',
#     'date': '2023-07-18T15:05:36Z'},
#    'message': 'Lab Done',
#    'tree': {'sha': 'd2f7404251841227048dee589a6dbada6d181bc7',
#     'url': 'https://api.github.com/repos/Cornelioz/lab-python-list-dict-set-comprehension/git/trees/d2f7404251841227048dee589a6dbada6d181bc7'},
#    'url': 'https://api.github.com/repos/Cornelioz/lab-python-list-dict-set-comprehension/git/commits/65a9fd646f479806ab7cd68073785eb87be702e6',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
'commit' in data[0].keys()
# Out:
# True

# %%
len('commit')
# Out:
# 6

# %%
pd.json_normalize(data).T
# Out:
#                                                                                0
# sha                                     65a9fd646f479806ab7cd68073785eb87be702e6
# node_id                        C_kwDOJ8j-o9oAKDY1YTlmZDY0NmY0Nzk4MDZhYjdjZDY4...
# url                            https://api.github.com/repos/Cornelioz/lab-pyt...
# html_url                       https://github.com/Cornelioz/lab-python-list-d...
# comments_url                   https://api.github.com/repos/Cornelioz/lab-pyt...
# parents                        [{'sha': '9c0ad4bae746e88f598f627b3f22d406c415...
# commit.author.name                                                    Nuno Silva
# commit.author.email                                       nunocornelio@gmail.com
# commit.author.date                                          2023-07-18T15:05:36Z
# commit.committer.name                                                 Nuno Silva
# commit.committer.email                                    nunocornelio@gmail.com
# ...
