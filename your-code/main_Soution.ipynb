# %%
import requests

from requests.auth import HTTPBasicAuth

from getpass import getpass
import pandas as pd

# %%
url="https://api.github.com/repos/ironhack-datalabs/datalis0819/forks"

response=requests.get(url,auth = HTTPBasicAuth('diogomerces', getpass()))
response
# Out:
# ········
# <Response [200]>

# %%
response.json()
# Out:
# [{'id': 259088458,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=',
#   'name': 'datalis0819',
#   'full_name': 'edxz7/datalis0819',
#   'private': False,
#   'owner': {'login': 'edxz7',
#    'id': 22061025,
#    'node_id': 'MDQ6VXNlcjIyMDYxMDI1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/22061025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edxz7',
#    'html_url': 'https://github.com/edxz7',
#    'followers_url': 'https://api.github.com/users/edxz7/followers',
#    'following_url': 'https://api.github.com/users/edxz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edxz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edxz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edxz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edxz7/orgs',
#    'repos_url': 'https://api.github.com/users/edxz7/repos',
# ...

# %%
pd.json_normalize(response.json()).head()
# Out:
#           id                           node_id         name  \
# 0  259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
#
#                     full_name  private  \
# 0           edxz7/datalis0819    False
# 1      Mariana427/datalis0819    False
# 2  EvelienDonkers/datalis0819    False
# 3     ta-data-lis/datalis0819    False
# 4            Inrx/datalis0819    False
#
#                                         html_url  \
# 0           https://github.com/edxz7/datalis0819
# 1      https://github.com/Mariana427/datalis0819
# 2  https://github.com/EvelienDonkers/datalis0819
# 3     https://github.com/ta-data-lis/datalis0819
# 4            https://github.com/Inrx/datalis0819
#
#                                     description  fork  \
# ...

# %%
print(pd.json_normalize(response.json()).head()["language"].unique())
# Out:
# [None 'Jupyter Notebook']

# %% [markdown]
# ### Challenge 2: Count Commits
# Assuming the main lab repo is ta-data-lis/lab-mysql-first-queries, you will count how many commits were made in the past 2 weeks:, you will count how many commits were made in the past 2 weeks:
#
# Obtain all the commits made in the past 2 weeks via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
url = 'https://api.github.com/repos/diogomerces/lab-numpy/commits'

# %%
response = requests.get(url, auth=HTTPBasicAuth('diogomerces', getpass()))
response
# Out:
# ········
# <Response [200]>

# %%
response.json()
# Out:
# [{'sha': 'daa7e65786665bac92844dd52a590c04e443d354',
#   'node_id': 'MDY6Q29tbWl0MjgyODg2Nzc1OmRhYTdlNjU3ODY2NjViYWM5Mjg0NGRkNTJhNTkwYzA0ZTQ0M2QzNTQ=',
#   'commit': {'author': {'name': 'diogomerces',
#     'email': '52171353+diogomerces@users.noreply.github.com',
#     'date': '2020-07-27T12:13:35Z'},
#    'committer': {'name': 'diogomerces',
#     'email': '52171353+diogomerces@users.noreply.github.com',
#     'date': '2020-07-27T12:13:35Z'},
#    'message': 'Create Solutions',
#    'tree': {'sha': 'd723e2a86cbee47edccf56a29160a850e360213e',
#     'url': 'https://api.github.com/repos/diogomerces/lab-numpy/git/trees/d723e2a86cbee47edccf56a29160a850e360213e'},
#    'url': 'https://api.github.com/repos/diogomerces/lab-numpy/git/commits/daa7e65786665bac92844dd52a590c04e443d354',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
data = pd.json_normalize(response.json())
data.head()
# Out:
#                                         sha  \
# 0  daa7e65786665bac92844dd52a590c04e443d354
# 1  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 2  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjgyODg2Nzc1OmRhYTdlNjU3ODY2NjViYW...
# 1  MDY6Q29tbWl0MjgyODg2Nzc1OjMyMTgyYTVmZjUyZWZjNW...
# 2  MDY6Q29tbWl0MjgyODg2Nzc1OjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                                  url  \
# 0  https://api.github.com/repos/diogomerces/lab-n...
# 1  https://api.github.com/repos/diogomerces/lab-n...
# 2  https://api.github.com/repos/diogomerces/lab-n...
#
#                                             html_url  \
# 0  https://github.com/diogomerces/lab-numpy/commi...
# 1  https://github.com/diogomerces/lab-numpy/commi...
# 2  https://github.com/diogomerces/lab-numpy/commi...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/diogomerces/lab-n...
# ...

# %%
data.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
data['commit.committer.date']
# Out:
# 0    2020-07-27T12:13:35Z
# 1    2019-10-23T13:28:37Z
# 2    2019-10-19T13:03:23Z
# Name: commit.committer.date, dtype: object

# %%
commi_date = (data['commit.committer.date'] > "2019-10-23T13:28:37Z")

commi_date[count]
commi_date[count].count()
# Out:
# 1
