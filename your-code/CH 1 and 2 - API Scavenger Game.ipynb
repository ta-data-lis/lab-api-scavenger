# %%
import requests
import json
import pandas as pd
import numpy as np
from requests.auth import HTTPBasicAuth
from getpass import getpass
from pandas.io.json import json_normalize

# %% [markdown]
# # Challenge 1

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'
response = requests.get(url)
#response = requests.get(url, auth = ........('beatrizrenault', getpass()))
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"id":219552641,"node_id":"MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=","name":"datalis0819","full_name":"Mariana427/datalis0819","private":false,"owner":{"login":"Mariana427","id":54869432,"node_id":"MDQ6VXNlcjU0ODY5NDMy","avatar_url":"https://avatars2.githubusercontent.com/u/54869432?v=4","gravatar_id":"","url":"https://api.github.com/users/Mariana427","html_url":"https://github.com/Mariana427","followers_url":"https://api.github.com/users/Mariana427/followers","following_url":"https://api.github.com/users/Mariana427/following{/other_user}","gists_url":"https://api.github.com/users/Mariana427/gists{/gist_id}","starred_url":"https://api.github.com/users/Mariana427/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Mariana427/subscriptions","organizations_url":"https://api.github.com/users/Mariana427/orgs","repos_url":"https://api.github.com/users/Mariana427/repos","events_url":"https://api.github.com/users/Mariana427/events{/privacy}","received_events_url":"https://api
# ...

# %%
ds = pd.DataFrame(response.json()) #it's not a jason file. is a html file. Gives an error 
ds.head(10)
# Out:
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7  201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8  201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
#
#                      full_name  private  \
# 0       Mariana427/datalis0819    False
# 1   EvelienDonkers/datalis0819    False
# 2      ta-data-lis/datalis0819    False
# 3             Inrx/datalis0819    False
# 4  filipamiralopes/datalis0819    False
# 5      janpotthoff/datalis0819    False
# ...

# %%
norm_json = json_normalize(response.json())
ds_normalized = pd.DataFrame(norm_json)
ds_normalized.head(10)
# Out:
#           id                           node_id         name  \
# 0  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 1  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 2  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 3  204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5  201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6  201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7  201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8  201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
#
#                      full_name  private  \
# 0       Mariana427/datalis0819    False
# 1   EvelienDonkers/datalis0819    False
# 2      ta-data-lis/datalis0819    False
# 3             Inrx/datalis0819    False
# 4  filipamiralopes/datalis0819    False
# 5      janpotthoff/datalis0819    False
# ...

# %%
list(ds_normalized.columns)
# Out:
# ['id',
#  'node_id',
#  'name',
#  'full_name',
#  'private',
#  'html_url',
#  'description',
#  'fork',
#  'url',
#  'forks_url',
#  'keys_url',
#  'collaborators_url',
#  'teams_url',
#  'hooks_url',
#  'issue_events_url',
#  'events_url',
#  'assignees_url',
#  'branches_url',
#  'tags_url',
#  'blobs_url',
#  'git_tags_url',
#  'git_refs_url',
#  'trees_url',
#  'statuses_url',
#  'languages_url',
#  'stargazers_url',
#  'contributors_url',
#  'subscribers_url',
#  'subscription_url',
#  'commits_url',
#  'git_commits_url',
#  'comments_url',
#  'issue_comment_url',
#  'contents_url',
#  'compare_url',
#  'merges_url',
#  'archive_url',
#  'downloads_url',
#  'issues_url',
#  'pulls_url',
#  'milestones_url',
#  'notifications_url',
#  'labels_url',
#  'releases_url',
#  'deployments_url',
#  'created_at',
#  'updated_at',
#  'pushed_at',
#  'git_url',
#  'ssh_url',
#  'clone_url',
#  'svn_url',
#  'homepage',
#  'size',
#  'stargazers_count',
#  'watchers_count',
# ...

# %%
ds_normalized['language']

language_at = np.array(ds_normalized['language'])
language_at
# Out:
# array([None, None, 'Jupyter Notebook', 'Jupyter Notebook',
#        'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook',
#        'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook',
#        'Jupyter Notebook', 'Jupyter Notebook'], dtype=object)

# %%
#Use an array to store the language attributes of each fork.

# %% [markdown]
# # Challenge 2

# %%
#ta-data-lis/lab-mysql-first-queries past 2weeks commits 
#via API, which is a JSON array that contains multiple commit objects.
#Count how many commit objects are contained in the array.

# %%
# ta-data-lis/lab-mysql-first-queries/commits
#https://api.github.com/ta-data-lis/lab-mysql-first-queries/commits

# %%
url2 = 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'
response2 = requests.get(url2)
#response = requests.get(url, auth = ........('beatrizrenault', getpass()))
response2
# Out:
# <Response [200]>

# %%
response2.text
# Out:
# '[{"sha":"6a243303cfd846faac16417cad54cd40ab3f82c6","node_id":"MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2ZmFhYzE2NDE3Y2FkNTRjZDQwYWIzZjgyYzY=","commit":{"author":{"name":"Carlos Madriz","email":"45972288+carlosmd14@users.noreply.github.com","date":"2019-08-19T11:12:15Z"},"committer":{"name":"GitHub","email":"noreply@github.com","date":"2019-08-19T11:12:15Z"},"message":"Update README.md","tree":{"sha":"5696a145dbbeef9a0417d852b706178bbca30900","url":"https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/trees/5696a145dbbeef9a0417d852b706178bbca30900"},"url":"https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/commits/6a243303cfd846faac16417cad54cd40ab3f82c6","comment_count":0,"verification":{"verified":true,"reason":"valid","signature":"-----BEGIN PGP SIGNATURE-----\\n\\nwsBcBAABCAAQBQJdWoQPCRBK7hj4Ov3rIwAAdHIIAJTBH5eUYEEp3WgPEtcI57ap\\nWOrVSW7+ff0RC/Gg24Oh8jJ/Ev4Km6s4n3/E/UdA2oJNaT1U2zSFJRmeHysxppEE\\nrmSSi4RChUeuHjK//QBzmY+5NuwFtC+aLCBPfsRxrYhzmGH7l
# ...

# %%
ds2 = pd.DataFrame(response2.json()) #it's not a jason file. is a html file. Gives an error 
ds2.head(10)
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carla Mendes', 'email': '...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# ...

# %%
norm_json2 = json_normalize(response2.json())
ds_normalized2 = pd.DataFrame(norm_json2)
ds_normalized2.head(10)
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# 2  https://api.github.com/repos/ta-data-lis/lab-m...
# 3  https://api.github.com/repos/ta-data-lis/lab-m...
#
#                                             html_url  \
# 0  https://github.com/ta-data-lis/lab-mysql-first...
# 1  https://github.com/ta-data-lis/lab-mysql-first...
# ...

# %%
list(ds_normalized2.columns)
# Out:
# ['sha',
#  'node_id',
#  'url',
#  'html_url',
#  'comments_url',
#  'parents',
#  'commit.author.name',
#  'commit.author.email',
#  'commit.author.date',
#  'commit.committer.name',
#  'commit.committer.email',
#  'commit.committer.date',
#  'commit.message',
#  'commit.tree.sha',
#  'commit.tree.url',
#  'commit.url',
#  'commit.comment_count',
#  'commit.verification.verified',
#  'commit.verification.reason',
#  'commit.verification.signature',
#  'commit.verification.payload',
#  'author.login',
#  'author.id',
#  'author.node_id',
#  'author.avatar_url',
#  'author.gravatar_id',
#  'author.url',
#  'author.html_url',
#  'author.followers_url',
#  'author.following_url',
#  'author.gists_url',
#  'author.starred_url',
#  'author.subscriptions_url',
#  'author.organizations_url',
#  'author.repos_url',
#  'author.events_url',
#  'author.received_events_url',
#  'author.type',
#  'author.site_admin',
#  'committer.login',
#  'committer.id',
#  'committer.node_id',
# ...

# %%
ds_normalized2['commit.author.date']

commit_date = np.array(ds_normalized2['commit.author.date'])
commit_date
# Out:
# array(['2019-08-19T11:12:15Z', '2019-08-19T11:11:55Z',
#        '2019-08-19T11:10:23Z', '2019-08-19T08:36:54Z'], dtype=object)

# %%
len(commit_date)
# Out:
# 4

# %%
#don't know how to filter the date
