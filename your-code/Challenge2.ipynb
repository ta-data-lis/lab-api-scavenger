# %%
import requests
import pandas as pd
#1 
token = '47ed47f0fb6a00aa2e0a20fbff63eda14cad7925'
git_url = 'https://api.github.com/repos/jonnyteronni/Ironhack_project_escapegame/commits'
#2
response = requests.get(git_url, auth=('jonnyteronni',token)).json()
forks_df = pd.DataFrame(response)
forks_df
# Out:
#                                         sha  \
# 0  3189efaa512d2400b133dbf45cddf8a0afec7ff7
# 1  aa58129be56b03944ad8c382b2daef5a87f2ed48
# 2  422dc5bbcc2145ebb8b45bea0800a4b2d9ffc4b4
# 3  969875bb8d69cc5e5fe2a325a8219c5d2592b07a
# 4  7b580119abde583be46b457406adc24d8c43c3ab
# 5  3a0f042b64cdd75a7363aee7742a7439f9a0147f
# 6  d87f5b9fbfdeeca89be8edec9f9f31b2d0ac4b56
# 7  f99e9d8df9f708284e82236725568406fb9fa1c5
# 8  86bc641b0a03936b2a0a815179f1c2f1b50c19a5
# 9  b2ad77937e077645aaa81ba67ea628bd36ee5517
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2MzY2NzM2OjMxODllZmFhNTEyZDI0MD...
# 1  MDY6Q29tbWl0Mjc2MzY2NzM2OmFhNTgxMjliZTU2YjAzOT...
# 2  MDY6Q29tbWl0Mjc2MzY2NzM2OjQyMmRjNWJiY2MyMTQ1ZW...
# 3  MDY6Q29tbWl0Mjc2MzY2NzM2Ojk2OTg3NWJiOGQ2OWNjNW...
# 4  MDY6Q29tbWl0Mjc2MzY2NzM2OjdiNTgwMTE5YWJkZTU4M2...
# 5  MDY6Q29tbWl0Mjc2MzY2NzM2OjNhMGYwNDJiNjRjZGQ3NW...
# 6  MDY6Q29tbWl0Mjc2MzY2NzM2OmQ4N2Y1YjlmYmZkZWVjYT...
# ...

# %%
commits_df = pd.json_normalize(response)
commits_df[commits_df['commit.author.date']>'2020-06-29']['sha'].count()
# Out:
# 10
