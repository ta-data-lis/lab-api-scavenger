# %%
    
import json
import requests
from requests.auth import HTTPBasicAuth

# %%
#First challenge

response = requests.get('https://api.github.com/repos/ironhack-datalabs/datalis0819/forks')
results = response.json()
results

data = pd.DataFrame(response.json())
data.head()
# Out:
#           id                           node_id         name  \
# 0  259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1  219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2  219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3  206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4  201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
#
#                      full_name  private  \
# 0            edxz7/datalis0819    False
# 1       Mariana427/datalis0819    False
# 2   EvelienDonkers/datalis0819    False
# 3      ta-data-lis/datalis0819    False
# 4  filipamiralopes/datalis0819    False
#
#                                                owner  \
# 0  {'login': 'edxz7', 'id': 22061025, 'node_id': ...
# 1  {'login': 'Mariana427', 'id': 54869432, 'node_...
# 2  {'login': 'EvelienDonkers', 'id': 55210096, 'n...
# 3  {'login': 'ta-data-lis', 'id': 54109907, 'node...
# 4  {'login': 'filipamiralopes', 'id': 42877871, '...
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
data.columns

data["languages_url"]
# Out:
# 0     https://api.github.com/repos/edxz7/datalis0819...
# 1     https://api.github.com/repos/Mariana427/datali...
# 2     https://api.github.com/repos/EvelienDonkers/da...
# 3     https://api.github.com/repos/ta-data-lis/datal...
# 4     https://api.github.com/repos/filipamiralopes/d...
# 5     https://api.github.com/repos/janpotthoff/datal...
# 6     https://api.github.com/repos/sofia-sousa/datal...
# 7     https://api.github.com/repos/naivm/datalis0819...
# 8     https://api.github.com/repos/LindaRit/datalis0...
# 9     https://api.github.com/repos/Ana-Andre/datalis...
# 10    https://api.github.com/repos/alonasorochynska/...
# 11    https://api.github.com/repos/carlarsmendes/dat...
# Name: languages_url, dtype: object

# %%
language_urls = [repo['languages_url'] for repo in response.json()]

test = [requests.get(lang_url,auth = HTTPBasicAuth("mboschbe","put token")).json() for lang_url in language_urls]

list1 = []
for i in test:
    list1.append(list(i.keys()))

list2 = [j for i in list1 for j in i]

set(list2)
# Out:
# {'HTML', 'Jupyter Notebook', 'Python', 'TSQL'}

# %%
#Second challenge

response = requests.get('https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/stats/commit_activity')
results = response.json()
results

data = pd.DataFrame(response.json())
data.head()

data.head()
# Out:
#    total        week                   days
# 0      0  1574553600  [0, 0, 0, 0, 0, 0, 0]
# 1      0  1575158400  [0, 0, 0, 0, 0, 0, 0]
# 2      0  1575763200  [0, 0, 0, 0, 0, 0, 0]
# 3      0  1576368000  [0, 0, 0, 0, 0, 0, 0]
# 4      0  1576972800  [0, 0, 0, 0, 0, 0, 0]

# %%
data["total"].sum()
# Out:
# 0
