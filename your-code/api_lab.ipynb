# %% [markdown]
# ## Challenge 1

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
from requests.models import HTTPBasicAuth

url = "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018"



url_fork = "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks"

token = "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"

response = requests.get(url_fork, auth = HTTPBasicAuth("marta-miguel", token))
forks = response.json()
forks

for fork in forks:
    print(fork["full_name"])
# Out:
# asier3/mad-oct-2018
# Medea22/mad-oct-2018
# techols/mad-oct-2018
# luisbang/mad-oct-2018
# Forastierii/mad-oct-2018
# ToniPons97/mad-oct-2018
# rsennes/mad-oct-2018
# gggfaria/mad-oct-2018
# nancyulric/mad-oct-2018
# lmartinezruizit/datamad0119
# eye8/madrid-oct-2018
# ArieHassan/madrid-oct-2018
# cmvalma/Ironhack-oct-2018
# criraca/madrid-oct-2018
# AlbertoCastellanos/madrid-oct-2018
# elenajpp/madrid-oct-2018
# miriammg/madrid-oct-2018
# albertogcmr/madrid-oct-2018
# marisfont/madrid-oct-2018

# %%
forks

languages = []

for fork in forks:
    languages.append(fork["language"])
    
languages = set(languages)
languages
# Out:
# {'HTML', 'Jupyter Notebook', None}

# %% [markdown]
# ## Challenge 2

# %%
url_commit = "https://api.github.com/repos/marta-miguel/lab-list-comprehensions/commits"

params = {"since":"2023-01-22"}

response = requests.get(url_commit, params = params)
response

two_weeks_commits = response.json()
two_weeks_commits
# Out:
# [{'sha': '18ed61207fd7cc2e8f110168b73e63865911b377',
#   'node_id': 'C_kwDOIyVfEdoAKDE4ZWQ2MTIwN2ZkN2NjMmU4ZjExMDE2OGI3M2U2Mzg2NTkxMWIzNzc',
#   'commit': {'author': {'name': 'Marta Miguel',
#     'email': 'marta.mfuni@gmail.com',
#     'date': '2023-01-22T19:33:40Z'},
#    'committer': {'name': 'Marta Miguel',
#     'email': 'marta.mfuni@gmail.com',
#     'date': '2023-01-22T19:33:40Z'},
#    'message': 'comment',
#    'tree': {'sha': '6f29c7a6c7b0e53e46cbba5c8ea04e368d2b67ff',
#     'url': 'https://api.github.com/repos/marta-miguel/lab-list-comprehensions/git/trees/6f29c7a6c7b0e53e46cbba5c8ea04e368d2b67ff'},
#    'url': 'https://api.github.com/repos/marta-miguel/lab-list-comprehensions/git/commits/18ed61207fd7cc2e8f110168b73e63865911b377',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
#2.
len(two_weeks_commits)
# Out:
# 1

# %%
pd.json_normalize(two_weeks_commits).T
# Out:
#                                                                                0
# sha                                     18ed61207fd7cc2e8f110168b73e63865911b377
# node_id                        C_kwDOIyVfEdoAKDE4ZWQ2MTIwN2ZkN2NjMmU4ZjExMDE2...
# url                            https://api.github.com/repos/marta-miguel/lab-...
# html_url                       https://github.com/marta-miguel/lab-list-compr...
# comments_url                   https://api.github.com/repos/marta-miguel/lab-...
# parents                        [{'sha': '8949a53afaeae22f5ce7eba669b73c4479c9...
# commit.author.name                                                  Marta Miguel
# commit.author.email                                        marta.mfuni@gmail.com
# commit.author.date                                          2023-01-22T19:33:40Z
# commit.committer.name                                               Marta Miguel
# commit.committer.email                                     marta.mfuni@gmail.com
# ...

# %%
len(pd.json_normalize(two_weeks_commits).T)
# Out:
# 57
