# %%
import pandas as pd
import requests
import json
from requests.auth import HTTPBasicAuth
from getpass import getpass

# %%
ds = pd.read_json(r'forks.json')
ds
# Out:
#            id                           node_id               name  \
# 0   237985234  MDEwOlJlcG9zaXRvcnkyMzc5ODUyMzQ=  lab-api-scavenger
# 1   237982710  MDEwOlJlcG9zaXRvcnkyMzc5ODI3MTA=  lab-api-scavenger
# 2   237981349  MDEwOlJlcG9zaXRvcnkyMzc5ODEzNDk=  lab-api-scavenger
# 3   237972159  MDEwOlJlcG9zaXRvcnkyMzc5NzIxNTk=  lab-api-scavenger
# 4   237965844  MDEwOlJlcG9zaXRvcnkyMzc5NjU4NDQ=  lab-api-scavenger
# 5   237959469  MDEwOlJlcG9zaXRvcnkyMzc5NTk0Njk=  lab-api-scavenger
# 6   237958933  MDEwOlJlcG9zaXRvcnkyMzc5NTg5MzM=  lab-api-scavenger
# 7   237957985  MDEwOlJlcG9zaXRvcnkyMzc5NTc5ODU=  lab-api-scavenger
# 8   237957176  MDEwOlJlcG9zaXRvcnkyMzc5NTcxNzY=  lab-api-scavenger
# 9   237956740  MDEwOlJlcG9zaXRvcnkyMzc5NTY3NDA=  lab-api-scavenger
# 10  237937270  MDEwOlJlcG9zaXRvcnkyMzc5MzcyNzA=  lab-api-scavenger
# 11  237935905  MDEwOlJlcG9zaXRvcnkyMzc5MzU5MDU=  lab-api-scavenger
# 12  237932925  MDEwOlJlcG9zaXRvcnkyMzc5MzI5MjU=  lab-api-scavenger
# ...

# %%
from pandas.io.json import json_normalize

df = pd.io.json.json_normalize(r'forks.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-08e22ff6cf55> in <module>
#       1 from pandas.io.json import json_normalize
#       2
# ----> 3 df = pd.io.json.json_normalize(r'forks.json')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     256
#     257     if record_path is None:
# --> 258         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     259             # naive normalization, this is idempotent for flat records
#     260             # and potentially will inflate the data considerably for
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     256
#     257     if record_path is None:
# --> 258         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...
