# %%
import requests
import pandas as pd 
from requests.auth import HTTPBasicAuth

# %%
#Chalenge 1

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

# %%
requests.get(url, auth = HTTPBasicAuth('rafaelmello82','Rbm@302323'))
# Out:
# <Response [200]>

# %%
response = requests.get(url, auth = HTTPBasicAuth('rafaelmello82','Rbm@302323'))

# %%
response.content
# Out:
# b'[{"id":259088458,"node_id":"MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=","name":"datalis0819","full_name":"edxz7/datalis0819","private":false,"owner":{"login":"edxz7","id":22061025,"node_id":"MDQ6VXNlcjIyMDYxMDI1","avatar_url":"https://avatars1.githubusercontent.com/u/22061025?v=4","gravatar_id":"","url":"https://api.github.com/users/edxz7","html_url":"https://github.com/edxz7","followers_url":"https://api.github.com/users/edxz7/followers","following_url":"https://api.github.com/users/edxz7/following{/other_user}","gists_url":"https://api.github.com/users/edxz7/gists{/gist_id}","starred_url":"https://api.github.com/users/edxz7/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/edxz7/subscriptions","organizations_url":"https://api.github.com/users/edxz7/orgs","repos_url":"https://api.github.com/users/edxz7/repos","events_url":"https://api.github.com/users/edxz7/events{/privacy}","received_events_url":"https://api.github.com/users/edxz7/received_events","type":"User","sit
# ...

# %%
response.json()
# Out:
# [{'id': 259088458,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=',
#   'name': 'datalis0819',
#   'full_name': 'edxz7/datalis0819',
#   'private': False,
#   'owner': {'login': 'edxz7',
#    'id': 22061025,
#    'node_id': 'MDQ6VXNlcjIyMDYxMDI1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/22061025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edxz7',
#    'html_url': 'https://github.com/edxz7',
#    'followers_url': 'https://api.github.com/users/edxz7/followers',
#    'following_url': 'https://api.github.com/users/edxz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edxz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edxz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edxz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edxz7/orgs',
#    'repos_url': 'https://api.github.com/users/edxz7/repos',
# ...

# %%
response.json()
# Out:
# [{'id': 259088458,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=',
#   'name': 'datalis0819',
#   'full_name': 'edxz7/datalis0819',
#   'private': False,
#   'owner': {'login': 'edxz7',
#    'id': 22061025,
#    'node_id': 'MDQ6VXNlcjIyMDYxMDI1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/22061025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edxz7',
#    'html_url': 'https://github.com/edxz7',
#    'followers_url': 'https://api.github.com/users/edxz7/followers',
#    'following_url': 'https://api.github.com/users/edxz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edxz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edxz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edxz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edxz7/orgs',
#    'repos_url': 'https://api.github.com/users/edxz7/repos',
# ...

# %%
response.json().keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-e8c3fcb045d4> in <module>
# ----> 1 response.json().keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
pd.DataFrame(response.json())
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# ...

# %%
response = pd.json_normalize(response.json())

# %%
response
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# ...

# %%
response.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
languages = []

for language in response['language'] :
    if language not in languages:
        languages.append(language)

# %%
languages
# Out:
# [None, 'Jupyter Notebook']

# %%
#Chalenge 2

# %%
url = 'https://api.github.com/repos/rafaelmello82/lab-tuple-set-dict/commits'

# %%
response = requests.get(url, auth = HTTPBasicAuth('rafaelmello82','Rbm@302323'))

# %%
response
# Out:
# <Response [200]>

# %%
response = pd.json_normalize(response.json())

# %%
response
# Out:
#                                         sha  \
# 0  c3e017b3c8f7127e7ca9af988dc20187f65ee352
# 1  6691543689dc811a868db4bb9579024926e23c17
# 2  785d03fbc615f0d95eff3caf5e559d2d15d8e894
# 3  e42f43ad93f16cb8cac01a4cfd21400272604ce0
# 4  264213002a7edad4987f34de1a0c9df19c1d4404
# 5  ee9bb7ce65fc380c225ddabc393c99c1193835e9
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2MTY1NjQzOmMzZTAxN2IzYzhmNzEyN2...
# 1  MDY6Q29tbWl0Mjc2MTY1NjQzOjY2OTE1NDM2ODlkYzgxMW...
# 2  MDY6Q29tbWl0Mjc2MTY1NjQzOjc4NWQwM2ZiYzYxNWYwZD...
# 3  MDY6Q29tbWl0Mjc2MTY1NjQzOmU0MmY0M2FkOTNmMTZjYj...
# 4  MDY6Q29tbWl0Mjc2MTY1NjQzOjI2NDIxMzAwMmE3ZWRhZD...
# 5  MDY6Q29tbWl0Mjc2MTY1NjQzOmVlOWJiN2NlNjVmYzM4MG...
#
#                                                  url  \
# 0  https://api.github.com/repos/rafaelmello82/lab...
# 1  https://api.github.com/repos/rafaelmello82/lab...
# 2  https://api.github.com/repos/rafaelmello82/lab...
# 3  https://api.github.com/repos/rafaelmello82/lab...
# ...

# %%
response['commit.author.date']
# Out:
# 0    2020-07-03T12:13:26Z
# 1    2020-06-29T19:12:29Z
# 2    2020-01-29T14:56:49Z
# 3    2019-10-22T08:45:43Z
# 4    2019-10-19T11:49:41Z
# 5    2019-10-19T11:48:24Z
# Name: commit.author.date, dtype: object

# %%
condition = (response['commit.author.date'] > "2019-12-22T08:45:43Z")

# %%
response[condition]
# Out:
#                                         sha  \
# 0  c3e017b3c8f7127e7ca9af988dc20187f65ee352
# 1  6691543689dc811a868db4bb9579024926e23c17
# 2  785d03fbc615f0d95eff3caf5e559d2d15d8e894
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2MTY1NjQzOmMzZTAxN2IzYzhmNzEyN2...
# 1  MDY6Q29tbWl0Mjc2MTY1NjQzOjY2OTE1NDM2ODlkYzgxMW...
# 2  MDY6Q29tbWl0Mjc2MTY1NjQzOjc4NWQwM2ZiYzYxNWYwZD...
#
#                                                  url  \
# 0  https://api.github.com/repos/rafaelmello82/lab...
# 1  https://api.github.com/repos/rafaelmello82/lab...
# 2  https://api.github.com/repos/rafaelmello82/lab...
#
#                                             html_url  \
# 0  https://github.com/rafaelmello82/lab-tuple-set...
# 1  https://github.com/rafaelmello82/lab-tuple-set...
# 2  https://github.com/rafaelmello82/lab-tuple-set...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/rafaelmello82/lab...
# ...

# %%
response[condition].count().head(1)
# Out:
# sha    3
# dtype: int64
