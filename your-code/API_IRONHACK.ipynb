# %%
import requests

# %% [markdown]
# # Challenge 1

# %%
response=requests.get("https://api.github.com/repos/ironhack-labs/data-labs/forks")

# %%
response.status_code
# Out:
# 200

# %%
import pandas as pd
import numpy as np
pd.DataFrame(response.json())
# Out:
#            id                           node_id       name  \
# 0   496436392                      R_kgDOHZcEqA  data-labs
# 1   356834479  MDEwOlJlcG9zaXRvcnkzNTY4MzQ0Nzk=  data-labs
# 2   338860344  MDEwOlJlcG9zaXRvcnkzMzg4NjAzNDQ=  data-labs
# 3   300911524  MDEwOlJlcG9zaXRvcnkzMDA5MTE1MjQ=  data-labs
# 4   299552330  MDEwOlJlcG9zaXRvcnkyOTk1NTIzMzA=  data-labs
# 5   299077226  MDEwOlJlcG9zaXRvcnkyOTkwNzcyMjY=  data-labs
# 6   297002633  MDEwOlJlcG9zaXRvcnkyOTcwMDI2MzM=  data-labs
# 7   296282127  MDEwOlJlcG9zaXRvcnkyOTYyODIxMjc=  data-labs
# 8   294753295  MDEwOlJlcG9zaXRvcnkyOTQ3NTMyOTU=  data-labs
# 9   292235639  MDEwOlJlcG9zaXRvcnkyOTIyMzU2Mzk=  data-labs
# 10  291691123  MDEwOlJlcG9zaXRvcnkyOTE2OTExMjM=  data-labs
# 11  281180175  MDEwOlJlcG9zaXRvcnkyODExODAxNzU=  data-labs
# 12  281180073  MDEwOlJlcG9zaXRvcnkyODExODAwNzM=  data-labs
# 13  275633107  MDEwOlJlcG9zaXRvcnkyNzU2MzMxMDc=  data-labs
# 14  272925285  MDEwOlJlcG9zaXRvcnkyNzI5MjUyODU=  data-labs
# ...

# %%
languages=[]
for element in response.json():
    languages.append(element["language"])

# %%
print(np.array(set(languages)))
# Out:
# {None, 'Jupyter Notebook'}

# %% [markdown]
# # Challenge 2

# %%
response=requests.get("https://api.github.com/repos/Pedro-ll/lab-list-comprehensions/commits")

# %%
response.status_code
# Out:
# 200

# %%
lista=[]
for element in response.json():
    lista.append(element["commit"])

pd.DataFrame(lista)
# Out:
#                                               author  \
# 0  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...
# 1  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...
# 2  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...
# 3  {'name': 'carlosmd14', 'email': 'carlosmadrizd...
# 4  {'name': 'carlosmd14', 'email': 'carlosmadrizd...
# 5  {'name': 'carlosmd14', 'email': 'carlosmadrizd...
#
#                                            committer            message  \
# 0  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...      final version
# 1  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...         lab test 2
# 2  {'name': 'Pedro Leal', 'email': 'pedrocamoesas...           lab test
# 3  {'name': 'carlosmd14', 'email': 'carlosmadrizd...  fixed repeated q5
# 4  {'name': 'carlosmd14', 'email': 'carlosmadrizd...       first commit
# 5  {'name': 'carlosmd14', 'email': 'carlosmadrizd...       first commit
#
#                                                 tree  \
# ...
