# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
#url = "https://api.github.com/repos/ironhack-datalabs/scavenger/tree/master/15024"
#curl https://api.github.com/search/code?q=addClass+in:file+language:js+repo:jquery/jquery

url = "https://api.github.com/search/code?q=In+in:file+language:txt+repo:ironhack-datalabs/scavenger"

response = requests.get(url).json()

response
# Out:
# {'total_count': 1,
#  'incomplete_results': False,
#  'items': [{'name': '.0001.scavengerhunt',
#    'path': '98750/.0001.scavengerhunt',
#    'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#    'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %%
ds = pd.DataFrame(response)
ds
# Out:
#    total_count  incomplete_results  \
# 0            1               False
#
#                                                items
# 0  {'name': '.0020.scavengerhunt', 'path': '55685...

# %%
#from Ines
#url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'

#from Miguel
url = 'https://api.github.com/search/code?q=filename:scavengerhunt+repo:ironhack-datalabs/scavenger'

#from Cristina
#url = 'https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger'
resp = requests.get(url).json()

#resp

#normalize? for what?

# %%
ds = pd.DataFrame(resp)
#ds

#list(ds)

# %%
#normalize
data = ds['items']

sorted_names = sorted(data, key = lambda x: x['name']) #put into a dataframe

print(sorted_names)

#nor_json = json_normalize(ds['items'].value[0])
#nor_json.head()

#print(sorted_names['names'])
# Out:
# [{'name': '.0001.scavengerhunt', 'path': '98750/.0001.scavengerhunt', 'sha': '2add7632f1323136324efbf38ec66db1838b6173', 'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.gi
# ...

# %%
ds1 = pd.DataFrame(sorted_names)
ds1
# Out:
#                    name                       path  \
# 0   .0001.scavengerhunt  98750/.0001.scavengerhunt
# 1   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 2   .0003.scavengerhunt  60224/.0003.scavengerhunt
# 3   .0004.scavengerhunt  68848/.0004.scavengerhunt
# 4   .0005.scavengerhunt  44639/.0005.scavengerhunt
# 5   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 6   .0007.scavengerhunt  17020/.0007.scavengerhunt
# 7   .0008.scavengerhunt  15534/.0008.scavengerhunt
# 8   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 9   .0010.scavengerhunt  47830/.0010.scavengerhunt
# 10  .0011.scavengerhunt  50896/.0011.scavengerhunt
# 11  .0012.scavengerhunt  15534/.0012.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 13  .0014.scavengerhunt  49418/.0014.scavengerhunt
# 14  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 15  .0016.scavengerhunt  47222/.0016.scavengerhunt
# 16  .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %%
#from here search by raw. how?

#application/vnd.github.VERSION.raw ?? (from documentation)
