# %%
import requests
import pandas as pd
from requests.auth import HTTPBasicAuth

# chllenge 1
url = 'https://api.github.com/user'

response = requests.get(url)

response = requests.get(url, auth = HTTPBasicAuth('migueltalambas', '127816Mt'))

response.json()
# Out:
# {'message': 'Requires authentication',
#  'documentation_url': 'https://docs.github.com/rest/reference/users#get-the-authenticated-user'}

# %%
url = 'https://api.github.com'

response = requests.get(url)

response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
pd.DataFrame(response.json()).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11252/1193289211.py in <module>
# ----> 1 pd.DataFrame(response.json()).head()
#
# ~\anaconda4\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda4\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda4\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda4\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
url1 = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

response1 = requests.get(url1)

# This gives me the full list of forks -> each row is a fork
df = pd.DataFrame(response1.json())
df
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 5   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 6   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 7   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 8   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 9   201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 10  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 11  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# 1        Mariana427/datalis0819    False
# 2    EvelienDonkers/datalis0819    False
# 3       ta-data-lis/datalis0819    False
# 4   filipamiralopes/datalis0819    False
# 5       janpotthoff/datalis0819    False
# 6       sofia-sousa/datalis0819    False
# 7             naivm/datalis0819    False
# 8          LindaRit/datalis0819    False
# 9         Ana-Andre/datalis0819    False
# 10       alonasorochynska/data2    False
# 11    carlarsmendes/datalis0819    False
#
#                                                 owner  \
# 0   {'login': 'edxz7', 'id': 22061025, 'node_id': ...
# 1   {'login': 'Mariana427', 'id': 54869432, 'node_...
# 2   {'login': 'EvelienDonkers', 'id': 55210096, 'n...
# 3   {'login': 'ta-data-lis', 'id': 54109907, 'node...
# 4   {'login': 'filipamiralopes', 'id': 42877871, '...
# 5   {'login': 'janpotthoff', 'id': 53485922, 'node...
# 6   {'login': 'sofia-sousa', 'id': 53151504, 'node...
# 7   {'login': 'naivm', 'id': 36080596, 'node_id': ...
# 8   {'login': 'LindaRit', 'id': 53478068, 'node_id...
# 9   {'login': 'Ana-Andre', 'id': 49027138, 'node_i...
# 10  {'login': 'alonasorochynska', 'id': 52972681, ...
# 11  {'login': 'carlarsmendes', 'id': 38359702, 'no...
#
#                                           html_url  \
# 0             https://github.com/edxz7/datalis0819
# 1        https://github.com/Mariana427/datalis0819
# 2    https://github.com/EvelienDonkers/datalis0819
# 3       https://github.com/ta-data-lis/datalis0819
# 4   https://github.com/filipamiralopes/datalis0819
# 5       https://github.com/janpotthoff/datalis0819
# 6       https://github.com/sofia-sousa/datalis0819
# 7             https://github.com/naivm/datalis0819
# 8          https://github.com/LindaRit/datalis0819
# 9         https://github.com/Ana-Andre/datalis0819
# 10       https://github.com/alonasorochynska/data2
# 11    https://github.com/carlarsmendes/datalis0819
#
#                                      description  fork  \
# 0   Data Analytics Full Time Lisbon, August 2019  True
# 1   Data Analytics Full Time Lisbon, August 2019  True
# 2   Data Analytics Full Time Lisbon, August 2019  True
# 3   Data Analytics Full Time Lisbon, August 2019  True
# 4   Data Analytics Full Time Lisbon, August 2019  True
# 5   Data Analytics Full Time Lisbon, August 2019  True
# 6   Data Analytics Full Time Lisbon, August 2019  True
# 7   Data Analytics Full Time Lisbon, August 2019  True
# 8   Data Analytics Full Time Lisbon, August 2019  True
# 9   Data Analytics Full Time Lisbon, August 2019  True
# 10  Data Analytics Full Time Lisbon, August 2019  True
# 11  Data Analytics Full Time Lisbon, August 2019  True
#
#                                                   url  ... open_issues_count  \
# 0      https://api.github.com/repos/edxz7/datalis0819  ...                 0
# 1   https://api.github.com/repos/Mariana427/datali...  ...                 0
# 2   https://api.github.com/repos/EvelienDonkers/da...  ...                 0
# 3   https://api.github.com/repos/ta-data-lis/datal...  ...                 0
# 4   https://api.github.com/repos/filipamiralopes/d...  ...                 0
# 5   https://api.github.com/repos/janpotthoff/datal...  ...                 0
# 6   https://api.github.com/repos/sofia-sousa/datal...  ...                 0
# 7      https://api.github.com/repos/naivm/datalis0819  ...                 0
# 8   https://api.github.com/repos/LindaRit/datalis0819  ...                 0
# 9   https://api.github.com/repos/Ana-Andre/datalis...  ...                 0
# 10  https://api.github.com/repos/alonasorochynska/...  ...                 0
# 11  https://api.github.com/repos/carlarsmendes/dat...  ...                 0
#
#                                               license allow_forking  \
# 0   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 1   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 2   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 3   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 4   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 5   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 6   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 7   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 8   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 9   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 10  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 11  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
#
#    is_template topics visibility forks open_issues watchers default_branch
# 0        False     []     public     0           0        0         master
# 1        False     []     public     0           0        0         master
# 2        False     []     public     0           0        0         master
# 3        False     []     public     0           0        0         master
# 4        False     []     public     0           0        0         master
# 5        False     []     public     0           0        0         master
# 6        False     []     public     0           0        0         master
# 7        False     []     public     0           0        0         master
# 8        False     []     public     0           0        0         master
# 9        False     []     public     0           0        0         master
# 10       False     []     public     0           0        0         master
# 11       False     []     public     0           0        0         master
#
# [12 rows x 77 columns]

# %%
import numpy as np

array_languages = list(df['language'])

unique = []

for element in array_languages:
    if element not in unique:
        unique.append(element)
        
unique
# Out:
# [None, 'Jupyter Notebook']

# %%
url= "https://api.github.com/repos/migueltalambas/lab-numpy/commits"
response= requests.get(url, auth= HTTPBasicAuth('migueltalambas','127816Mt'))
response
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(response.json())
df
# Out:
#                                         sha  \
# 0  8b10b52dce6a3e553179198cac884b55d30dac62
# 1  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 2  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  C_kwDOGuSZ8NoAKDhiMTBiNTJkY2U2YTNlNTUzMTc5MTk4...
# 1  MDY6Q29tbWl0NDUxMTg5MjMyOjMyMTgyYTVmZjUyZWZjNW...
# 2  MDY6Q29tbWl0NDUxMTg5MjMyOjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                               commit  \
# 0  {'author': {'name': 'Miguel Talambas', 'email'...
# 1  {'author': {'name': 'carlosmd14', 'email': 'ca...
# 2  {'author': {'name': 'carlosmd14', 'email': 'ca...
#
#                                                  url  \
# 0  https://api.github.com/repos/migueltalambas/la...
# 1  https://api.github.com/repos/migueltalambas/la...
# 2  https://api.github.com/repos/migueltalambas/la...
#
#                                             html_url  \
# 0  https://github.com/migueltalambas/lab-numpy/co...
# 1  https://github.com/migueltalambas/lab-numpy/co...
# 2  https://github.com/migueltalambas/lab-numpy/co...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/migueltalambas/la...
# 1  https://api.github.com/repos/migueltalambas/la...
# 2  https://api.github.com/repos/migueltalambas/la...
#
#                                               author  \
# 0  {'login': 'migueltalambas', 'id': 97064159, 'n...
# 1  {'login': 'Madrizing', 'id': 45972288, 'node_i...
# 2  {'login': 'Madrizing', 'id': 45972288, 'node_i...
#
#                                            committer  \
# 0  {'login': 'migueltalambas', 'id': 97064159, 'n...
# 1  {'login': 'Madrizing', 'id': 45972288, 'node_i...
# 2  {'login': 'Madrizing', 'id': 45972288, 'node_i...
#
#                                              parents
# 0  [{'sha': '32182a5ff52efc5db9f6fd880d1dfaa342ce...
# 1  [{'sha': '5058eb476c7f14631f82e276fc9cbd5fc376...
# 2                                                 []

# %%
df =pd.json_normalize(response.json())
df
# Out:
#                                         sha  \
# 0  8b10b52dce6a3e553179198cac884b55d30dac62
# 1  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 2  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  C_kwDOGuSZ8NoAKDhiMTBiNTJkY2U2YTNlNTUzMTc5MTk4...
# 1  MDY6Q29tbWl0NDUxMTg5MjMyOjMyMTgyYTVmZjUyZWZjNW...
# 2  MDY6Q29tbWl0NDUxMTg5MjMyOjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                                  url  \
# 0  https://api.github.com/repos/migueltalambas/la...
# 1  https://api.github.com/repos/migueltalambas/la...
# 2  https://api.github.com/repos/migueltalambas/la...
#
#                                             html_url  \
# 0  https://github.com/migueltalambas/lab-numpy/co...
# 1  https://github.com/migueltalambas/lab-numpy/co...
# 2  https://github.com/migueltalambas/lab-numpy/co...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/migueltalambas/la...
# 1  https://api.github.com/repos/migueltalambas/la...
# 2  https://api.github.com/repos/migueltalambas/la...
#
#                                              parents commit.author.name  \
# 0  [{'sha': '32182a5ff52efc5db9f6fd880d1dfaa342ce...    Miguel Talambas
# 1  [{'sha': '5058eb476c7f14631f82e276fc9cbd5fc376...         carlosmd14
# 2                                                 []         carlosmd14
#
#          commit.author.email    commit.author.date commit.committer.name  ...  \
# 0  migueltalambas4@gmail.com  2022-01-24T18:06:46Z       Miguel Talambas  ...
# 1    carlosmadrizd@gmail.com  2019-10-23T13:28:37Z            carlosmd14  ...
# 2    carlosmadrizd@gmail.com  2019-10-19T13:03:23Z            carlosmd14  ...
#
#                              committer.following_url  \
# 0  https://api.github.com/users/migueltalambas/fo...
# 1  https://api.github.com/users/Madrizing/followi...
# 2  https://api.github.com/users/Madrizing/followi...
#
#                                  committer.gists_url  \
# 0  https://api.github.com/users/migueltalambas/gi...
# 1  https://api.github.com/users/Madrizing/gists{/...
# 2  https://api.github.com/users/Madrizing/gists{/...
#
#                                committer.starred_url  \
# 0  https://api.github.com/users/migueltalambas/st...
# 1  https://api.github.com/users/Madrizing/starred...
# 2  https://api.github.com/users/Madrizing/starred...
#
#                          committer.subscriptions_url  \
# 0  https://api.github.com/users/migueltalambas/su...
# 1  https://api.github.com/users/Madrizing/subscri...
# 2  https://api.github.com/users/Madrizing/subscri...
#
#                         committer.organizations_url  \
# 0  https://api.github.com/users/migueltalambas/orgs
# 1       https://api.github.com/users/Madrizing/orgs
# 2       https://api.github.com/users/Madrizing/orgs
#
#                                  committer.repos_url  \
# 0  https://api.github.com/users/migueltalambas/repos
# 1       https://api.github.com/users/Madrizing/repos
# 2       https://api.github.com/users/Madrizing/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/migueltalambas/ev...
# 1  https://api.github.com/users/Madrizing/events{...
# 2  https://api.github.com/users/Madrizing/events{...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/migueltalambas/re...           User
# 1  https://api.github.com/users/Madrizing/receive...           User
# 2  https://api.github.com/users/Madrizing/receive...           User
#
#   committer.site_admin
# 0                False
# 1                False
# 2                False
#
# [3 rows x 57 columns]

# %%
condition = df['commit.author.date'] > '2020-07-01T12:35:49Z'

df[condition]['commit.author.date'].count()
# Out:
# 1
