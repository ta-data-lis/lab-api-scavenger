# %%
import requests
import pandas as pd
from requests.auth import HTTPBasicAuth

# chllenge 1
url = 'https://api.github.com/user'

response = requests.get(url)

response = requests.get(url, auth = HTTPBasicAuth('Goncalo-Nobre', 'PWFGXYms3850!'))

response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
# ...

# %%
url = 'https://api.github.com'

response = requests.get(url)

response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
# ...

# %%
pd.DataFrame(response.json()).head()
# Out:
#                        login        id               node_id  \
# collaborators  Goncalo-Nobre  66629614  MDQ6VXNlcjY2NjI5NjE0
# name           Goncalo-Nobre  66629614  MDQ6VXNlcjY2NjI5NjE0
# private_repos  Goncalo-Nobre  66629614  MDQ6VXNlcjY2NjI5NjE0
# space          Goncalo-Nobre  66629614  MDQ6VXNlcjY2NjI5NjE0
#
#                                                       avatar_url gravatar_id  \
# collaborators  https://avatars2.githubusercontent.com/u/66629...
# name           https://avatars2.githubusercontent.com/u/66629...
# private_repos  https://avatars2.githubusercontent.com/u/66629...
# space          https://avatars2.githubusercontent.com/u/66629...
#
#                                                       url  \
# collaborators  https://api.github.com/users/Goncalo-Nobre
# name           https://api.github.com/users/Goncalo-Nobre
# private_repos  https://api.github.com/users/Goncalo-Nobre
# space          https://api.github.com/users/Goncalo-Nobre
#
# ...

# %%
url1 = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/forks'

response1 = requests.get(url1)

# This gives me the full list of forks -> each row is a fork
df = pd.DataFrame(response1.json())
df
# Out:
#            id                           node_id         name  \
# 0   259088458  MDEwOlJlcG9zaXRvcnkyNTkwODg0NTg=  datalis0819
# 1   219552641  MDEwOlJlcG9zaXRvcnkyMTk1NTI2NDE=  datalis0819
# 2   219547548  MDEwOlJlcG9zaXRvcnkyMTk1NDc1NDg=  datalis0819
# 3   206122694  MDEwOlJlcG9zaXRvcnkyMDYxMjI2OTQ=  datalis0819
# 4   204513290  MDEwOlJlcG9zaXRvcnkyMDQ1MTMyOTA=  datalis0819
# 5   201974388  MDEwOlJlcG9zaXRvcnkyMDE5NzQzODg=  datalis0819
# 6   201961477  MDEwOlJlcG9zaXRvcnkyMDE5NjE0Nzc=  datalis0819
# 7   201956190  MDEwOlJlcG9zaXRvcnkyMDE5NTYxOTA=  datalis0819
# 8   201956175  MDEwOlJlcG9zaXRvcnkyMDE5NTYxNzU=  datalis0819
# 9   201956108  MDEwOlJlcG9zaXRvcnkyMDE5NTYxMDg=  datalis0819
# 10  201956049  MDEwOlJlcG9zaXRvcnkyMDE5NTYwNDk=  datalis0819
# 11  199482969  MDEwOlJlcG9zaXRvcnkxOTk0ODI5Njk=        data2
# 12  198705694  MDEwOlJlcG9zaXRvcnkxOTg3MDU2OTQ=  datalis0819
#
#                       full_name  private  \
# 0             edxz7/datalis0819    False
# ...

# %%
import numpy as np

array_languages = list(df['language'])

unique = []

for element in array_languages:
    if element not in unique:
        unique.append(element)
        
unique
# Out:
# [None, 'Jupyter Notebook']

# %%
# Chalenge 2!

# %%
url= "https://api.github.com/repos/Goncalo-Nobre/lab-numpy/commits"
response= requests.get(url, auth= HTTPBasicAuth('Goncalo-Nobre','PWFGXYms3850!'))
response
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(response.json())
df
# Out:
#                                         sha  \
# 0  6bdc090f83914fa9f62a31ba4da293383279b86a
# 1  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 2  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjI4OjZiZGMwOTBmODM5MTRmYT...
# 1  MDY6Q29tbWl0Mjc2NjIwNjI4OjMyMTgyYTVmZjUyZWZjNW...
# 2  MDY6Q29tbWl0Mjc2NjIwNjI4OjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                               commit  \
# 0  {'author': {'name': 'Gonçalo Nobre', 'email': ...
# 1  {'author': {'name': 'carlosmd14', 'email': 'ca...
# 2  {'author': {'name': 'carlosmd14', 'email': 'ca...
#
#                                                  url  \
# 0  https://api.github.com/repos/Goncalo-Nobre/lab...
# 1  https://api.github.com/repos/Goncalo-Nobre/lab...
# 2  https://api.github.com/repos/Goncalo-Nobre/lab...
#
#                                             html_url  \
# 0  https://github.com/Goncalo-Nobre/lab-numpy/com...
# ...

# %%
df =pd.json_normalize(response.json())
df
# Out:
#                                         sha  \
# 0  6bdc090f83914fa9f62a31ba4da293383279b86a
# 1  32182a5ff52efc5db9f6fd880d1dfaa342ce2139
# 2  5058eb476c7f14631f82e276fc9cbd5fc3762de0
#
#                                              node_id  \
# 0  MDY6Q29tbWl0Mjc2NjIwNjI4OjZiZGMwOTBmODM5MTRmYT...
# 1  MDY6Q29tbWl0Mjc2NjIwNjI4OjMyMTgyYTVmZjUyZWZjNW...
# 2  MDY6Q29tbWl0Mjc2NjIwNjI4OjUwNThlYjQ3NmM3ZjE0Nj...
#
#                                                  url  \
# 0  https://api.github.com/repos/Goncalo-Nobre/lab...
# 1  https://api.github.com/repos/Goncalo-Nobre/lab...
# 2  https://api.github.com/repos/Goncalo-Nobre/lab...
#
#                                             html_url  \
# 0  https://github.com/Goncalo-Nobre/lab-numpy/com...
# 1  https://github.com/Goncalo-Nobre/lab-numpy/com...
# 2  https://github.com/Goncalo-Nobre/lab-numpy/com...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/Goncalo-Nobre/lab...
# ...

# %%
condition = df['commit.author.date'] > '2020-07-01T12:35:49Z'

df[condition]['commit.author.date'].count()
# Out:
# 1
