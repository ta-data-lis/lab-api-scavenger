# %%
import pandas as pd
import requests
import json

# %%
#CHALLENGE 1
#tip1
#GET /repos/:owner/:repo/forks

#url = "https://api.github.com/users/FranciscoAfra216/repos"
#url = 'https://github.com/ironhack-datalabs/bcn-feb-2019'
url= 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks'
#is this the correct URL??
response = requests.get(url)

print(response) # if 200 OK
list(response)
# Out:
# <Response [200]>
# [b'[{"id":307424216,"node_id":"MDEwOlJlcG9zaXRvcnkzMDc0MjQyMTY=","name":"bcn-feb-2019","full_name":"ulrichglass/bcn-feb-2019","priv',
#  b'ate":false,"owner":{"login":"ulrichglass","id":67161991,"node_id":"MDQ6VXNlcjY3MTYxOTkx","avatar_url":"https://avatars2.githubus',
#  b'ercontent.com/u/67161991?v=4","gravatar_id":"","url":"https://api.github.com/users/ulrichglass","html_url":"https://github.com/u',
#  b'lrichglass","followers_url":"https://api.github.com/users/ulrichglass/followers","following_url":"https://api.github.com/users/u',
#  b'lrichglass/following{/other_user}","gists_url":"https://api.github.com/users/ulrichglass/gists{/gist_id}","starred_url":"https:/',
#  b'/api.github.com/users/ulrichglass/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ulrichglass/subscrip',
#  b'tions","organizations_url":"https://api.github.com/users/ulrichglass/orgs","repos_url":"https://api.github.com/users/ulrichglass',
# ...

# %%
response.json()
# Out:
# [{'id': 307424216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDc0MjQyMTY=',
#   'name': 'bcn-feb-2019',
#   'full_name': 'ulrichglass/bcn-feb-2019',
#   'private': False,
#   'owner': {'login': 'ulrichglass',
#    'id': 67161991,
#    'node_id': 'MDQ6VXNlcjY3MTYxOTkx',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/67161991?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ulrichglass',
#    'html_url': 'https://github.com/ulrichglass',
#    'followers_url': 'https://api.github.com/users/ulrichglass/followers',
#    'following_url': 'https://api.github.com/users/ulrichglass/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ulrichglass/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ulrichglass/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ulrichglass/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ulrichglass/orgs',
# ...

# %%
# There is a function in pandas to do this, but it makes some assumptions and sometimes we have to unpack hierarchical structures ourselves
resultsdf=pd.json_normalize(response.json()).head(10)

# %%
resultsdf['language']
#We can see that 1 different languages is used in this user repos
resultsdf['language'].unique()
# Out:
# array([None, 'Jupyter Notebook'], dtype=object)

# %%
#CHALLENGE 2
#url='https://api.github.com/ta-data-lis/lab-mysql-first-queries'
#url= 'https://api.github.com/users/ironhack-datalabs/repos'
url='https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'    
response = requests.get(url, params={'since':'2020-10-12T00:00:00+00:00'})

print(response) # if 200 OK
list(response)

#We get an empty 'body' because there where no commits in the past 2weeks, 
#therefore I will apply this exercise to a lab of mine that had been commited in the past 2 weeks
#Sorry José, more work for you to evaluate xD
# Out:
# <Response [200]>
# [b'[]']

# %%
url='https://api.github.com/repos/FranciscoAfra216/lab-mysql-first-queries/commits'
response = requests.get(url, params={'since':'2020-10-12T00:00:00+00:00'})

print(response) # if 200 OK, otherwise bad URL provided
list(response)
# Out:
# <Response [200]>
# [b'[{"sha":"a77a88d81bbfdeb15a1091117dd3709b0ad2a78c","node_id":"MDY6Q29tbWl0MzA1Mzg1MTA3OmE3N2E4OGQ4MWJiZmRlYjE1YTEwOTExMTdkZDM3MD',
#  b'liMGFkMmE3OGM=","commit":{"author":{"name":"FranciscoAfra216","email":"franciscoafrapedro@gmail.com","date":"2020-10-19T15:47:51',
#  b'Z"},"committer":{"name":"FranciscoAfra216","email":"franciscoafrapedro@gmail.com","date":"2020-10-19T15:47:51Z"},"message":"Push',
#  b'ing the 1st mySQL lab challenge","tree":{"sha":"f73da79cfd14acff2d6d06ccd809e210017d7934","url":"https://api.github.com/repos/Fr',
#  b'anciscoAfra216/lab-mysql-first-queries/git/trees/f73da79cfd14acff2d6d06ccd809e210017d7934"},"url":"https://api.github.com/repos/',
#  b'FranciscoAfra216/lab-mysql-first-queries/git/commits/a77a88d81bbfdeb15a1091117dd3709b0ad2a78c","comment_count":0,"verification":',
#  b'{"verified":false,"reason":"unsigned","signature":null,"payload":null}},"url":"https://api.github.com/repos/FranciscoAfra216/lab',
# ...

# %%
mylabjson = response.json()
mylabdf=pd.DataFrame(mylabjson)
mylabdf
# Out:
#                                         sha  \
# 0  a77a88d81bbfdeb15a1091117dd3709b0ad2a78c
# 1  452fee1b239c4f8a636bbdcf3aa7808f1181623c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MzA1Mzg1MTA3OmE3N2E4OGQ4MWJiZmRlYj...
# 1  MDY6Q29tbWl0MzA1Mzg1MTA3OjQ1MmZlZTFiMjM5YzRmOG...
#
#                                               commit  \
# 0  {'author': {'name': 'FranciscoAfra216', 'email...
# 1  {'author': {'name': 'FranciscoAfra216', 'email...
#
#                                                  url  \
# 0  https://api.github.com/repos/FranciscoAfra216/...
# 1  https://api.github.com/repos/FranciscoAfra216/...
#
#                                             html_url  \
# 0  https://github.com/FranciscoAfra216/lab-mysql-...
# 1  https://github.com/FranciscoAfra216/lab-mysql-...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/FranciscoAfra216/...
# 1  https://api.github.com/repos/FranciscoAfra216/...
#
# ...

# %%
mylabdf['commit'].count()
#In the past 2 weeks Francisco made 2 commits to his forked repo 'lab-my-sql-first-queries' from ta-data-lis
# Out:
# 2
