# %%
import pandas as pd
import requests

# %%
github_token = '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'
repo_owner = 'ironhack-datalabs'
repo_name = 'madrid-oct-2018'


def get_forks_list(repo_owner, repo_name, github_token):
    headers = {
        'Authorization': f'Token {github_token}'
    }

    url = f'https://api.github.com/repos/{repo_owner}/{repo_name}/forks'
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch forks. Status code: {response.status_code}")
        return None

forks_list = get_forks_list(repo_owner, repo_name, github_token)
forks_list
# Out:
# [{'id': 487632383,
#   'node_id': 'R_kgDOHRCt_w',
#   'name': 'mad-oct-2018',
#   'full_name': 'asier3/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'asier3',
#    'id': 101799204,
#    'node_id': 'U_kgDOBhFVJA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101799204?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asier3',
#    'html_url': 'https://github.com/asier3',
#    'followers_url': 'https://api.github.com/users/asier3/followers',
#    'following_url': 'https://api.github.com/users/asier3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asier3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/asier3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asier3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/asier3/orgs',
#    'repos_url': 'https://api.github.com/users/asier3/repos',
# ...

# %%
data_forks = pd.DataFrame(forks_list)
print(data_forks)
# Out:
#            id                           node_id               name  \
# 0   487632383                      R_kgDOHRCt_w       mad-oct-2018
# 1   485472962                      R_kgDOHO-6wg       mad-oct-2018
# 2   416830289                      R_kgDOGNhTUQ       mad-oct-2018
# 3   357335874  MDEwOlJlcG9zaXRvcnkzNTczMzU4NzQ=       mad-oct-2018
# 4   335309218  MDEwOlJlcG9zaXRvcnkzMzUzMDkyMTg=       mad-oct-2018
# 5   204100911  MDEwOlJlcG9zaXRvcnkyMDQxMDA5MTE=       mad-oct-2018
# 6   200138127  MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=       mad-oct-2018
# 7   198273438  MDEwOlJlcG9zaXRvcnkxOTgyNzM0Mzg=       mad-oct-2018
# 8   167001044  MDEwOlJlcG9zaXRvcnkxNjcwMDEwNDQ=        datamad0119
# 9   162498469  MDEwOlJlcG9zaXRvcnkxNjI0OTg0Njk=    madrid-oct-2018
# 10  154625001  MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=    madrid-oct-2018
# 11  154291113  MDEwOlJlcG9zaXRvcnkxNTQyOTExMTM=  Ironhack-oct-2018
# 12  154191482  MDEwOlJlcG9zaXRvcnkxNTQxOTE0ODI=    madrid-oct-2018
# ...

# %%
repo_url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018"

response = requests.get(f"{repo_url}/forks")

for fork in forks:
    language = fork.get("language")
    if language and language not in languages:
        languages.append(language)

print(languages)
# Out:
# ['Jupyter Notebook', 'HTML', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'HTML', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'HTML', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
import requests
from datetime import datetime, timedelta
import time

owner = "Dulce-04"
repo = "lab-list-comprehensions"

commits_url = f"https://api.github.com/repos/{owner}/{repo}/commits"

two_weeks_ago = (datetime.now() - timedelta(weeks=2)).isoformat()

params = {
    "since": two_weeks_ago
}

def fetch_commits():
    max_retries = 5
    retries = 0
    while retries < max_retries:
        response = requests.get(commits_url, params=params)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Failed to fetch commits. Status code: {response.status_code}")
            retries += 1
            time.sleep(5) 
    return []

commits = fetch_commits_with_retries()

commit_count = len(commits)
print(f"Number of commits in the past 2 weeks: {commit_count}")
# Out:
# Failed to fetch commits. Status code: 404
# Failed to fetch commits. Status code: 404
# Failed to fetch commits. Status code: 404
# Failed to fetch commits. Status code: 404
# Failed to fetch commits. Status code: 404
# Number of commits in the past 2 weeks: 0
