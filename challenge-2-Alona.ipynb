# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datalis0819/commits'
response = requests.get(url, auth=('alonasorochynska','a8a999d03a8738456229d79040a65bb26f76c4b6')).json()
#response = requests.get(url).json()
response
ds = pd.DataFrame(response)
ds.head()
# Out:
#                                               author  \
# 0  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 1  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 2  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 3  {'login': 'carlosmd14', 'id': 45972288, 'node_...
# 4  {'login': 'carlosmd14', 'id': 45972288, 'node_...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                               commit  \
# 0  {'author': {'name': 'Carlos Madriz', 'email': ...
# 1  {'author': {'name': 'Carlos Madriz', 'email': ...
# 2  {'author': {'name': 'Carlos Madriz', 'email': ...
# 3  {'author': {'name': 'Carlos Madriz', 'email': ...
# ...

# %%
ds_json = json_normalize(response) 
ds_normalized = pd.DataFrame(ds_json) 
ds_normalized.head()
# Out:
#                                    author.avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/45972...
# 1  https://avatars2.githubusercontent.com/u/45972...
# 2  https://avatars2.githubusercontent.com/u/45972...
# 3  https://avatars2.githubusercontent.com/u/45972...
# 4  https://avatars2.githubusercontent.com/u/45972...
#
#                                    author.events_url  \
# 0  https://api.github.com/users/carlosmd14/events...
# 1  https://api.github.com/users/carlosmd14/events...
# 2  https://api.github.com/users/carlosmd14/events...
# 3  https://api.github.com/users/carlosmd14/events...
# 4  https://api.github.com/users/carlosmd14/events...
#
#                                 author.followers_url  \
# 0  https://api.github.com/users/carlosmd14/followers
# 1  https://api.github.com/users/carlosmd14/followers
# 2  https://api.github.com/users/carlosmd14/followers
# 3  https://api.github.com/users/carlosmd14/followers
# ...

# %%
ds_normalized.columns
# Out:
# Index(['author.avatar_url', 'author.events_url', 'author.followers_url',
#        'author.following_url', 'author.gists_url', 'author.gravatar_id',
#        'author.html_url', 'author.id', 'author.login', 'author.node_id',
#        'author.organizations_url', 'author.received_events_url',
#        'author.repos_url', 'author.site_admin', 'author.starred_url',
#        'author.subscriptions_url', 'author.type', 'author.url', 'comments_url',
#        'commit.author.date', 'commit.author.email', 'commit.author.name',
#        'commit.comment_count', 'commit.committer.date',
#        'commit.committer.email', 'commit.committer.name', 'commit.message',
#        'commit.tree.sha', 'commit.tree.url', 'commit.url',
#        'commit.verification.payload', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.verified',
#        'committer.avatar_url', 'committer.events_url',
#        'committer.followers_url', 'committer.following_url',
# ...

# %%
ds_normalized[['commit.author.name', 'commit.author.date']].head()
# Out:
#   commit.author.name    commit.author.date
# 0      Carlos Madriz  2019-08-14T10:31:56Z
# 1      Carlos Madriz  2019-08-13T07:46:30Z
# 2      Carlos Madriz  2019-08-13T07:43:52Z
# 3      Carlos Madriz  2019-08-13T07:43:45Z
# 4      Carlos Madriz  2019-08-13T07:43:39Z

# %%
#new_ds = ds_normalized.groupby(["date"]).agg({'bitcoin_rate':'mean'}).reset_index()
#new_ds

# %%
ds_normalized = ['commit_date']
ds_normalized
# Out:
# ['commit_date']

# %%
ds_normalized['commit_date'] = [ds_normalized[x] for x in range(len(ds_normalized['commit.author.date']))]
#new_ds = pd.DataFrame(ds_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-76609630e020> in <module>
# ----> 1 ds_normalized['commit_date'] = [ds_normalized[x] for x in range(len(ds_normalized['commit.author.date']))]
#       2 #new_ds = pd.DataFrame(ds_date)
#
# TypeError: list indices must be integers or slices, not str
